# %% [markdown]
# # 1 Time Series 7-Day Forecasting with multi-layer perceptron (MLP)<a id='1_time_series_7-day_forecasting_with_mlp'></a>

# %% [markdown]
# ## 1.1 Contents<a id='1.1_contents'></a>
# * [1 Time series 7-day forecasting with MLP](#1_time_series_7-day_forecasting_with_mlp)
#   * [1.1 Contents](#1.1_contents)
#   * [1.2 Imports](#1.2_imports)
#   * [1.3 Functions](#1.3_functions)
#       * [1.3.1 Function: feature_list](#1.3.1_feature_list)
#       * [1.3.2 Function: ebd_dim](#1.3.2_ebd_dim)
#       * [1.3.3 Function: split_sequences](#1.3.3_split_sequences)
#       * [1.3.4 Function: to_embed](#1.3.4_to_embed)
#       * [1.3.5 Function: build_MLP with embeddings](#1.3.5_build_MLP_with_embeddings)
#       * [1.3.6 Function: ndarray_to_input_list](#1.3.6_ndarray_to_input_list)
#       * [1.3.7 Function: ginic](#1.3.7_ginic)
#       * [1.3.8 Function: gini_normalizedc](#1.3.8_gini_normalizedc)
#       * [1.3.9 Functions: rmse_y_y_pred](#1.3.9_rmse_y_y_pred)
#       * [1.3.10 Functions: plot_test_set](#1.3.10_plot_test_set)
#   * [1.5 Preprocessing](#1.5_preprocessing)
#       * [1.5.1 Preprocessing: get feature and target for model training and testing with cross-validation](#1.5.1_get_feature_target)
#       * [1.5.2 Preprocessing: scale feature and target variables](#1.5.2_scale_feature_target)
#   * [1.6 Train and test the MLP model](#1.6_train_test_model)
#       * [1.6.1 Train and test the MLP model: train and test with cross-validation](#1.6.1_train_test_crossvalidation)
#       * [1.6.2 Summary and plot the model](#1.6.2_summary_plot_model)
#   * [1.7 Organize and evaluate model performance](#1.7_organize_evaludate_model)
#       * [1.7.1 Organize and evaluate model performance: train set](#1.7.1_organize_evaludate_model_train)
#       * [1.7.2 Organize and evaluate model performance: validation set](#1.7.2_organize_evaludate_model_validation)
#       * [1.7.3 Organize and evaluate model performance: test set](#1.7.3_organize_evaludate_model_test)
#       * [1.7.4 Organize and evaluate model performance: save](#1.7.4_organize_evaludate_model_save)
#       * [1.7.5 Organize and evaluate model performance: plot](#1.7.5_organize_evaludate_model_plot)

# %% [markdown]
# ## 1.2 Imports<a id='1.2_imports'></a>

# %%
from google.colab import drive # (in Colab)
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The version needs to be identical to the version used to save the pickle file with pd.dataframes
# !pip install pandas==1.3.1 
# !pip install scipy==1.6.2
# !pip install scikit-learn==0.24.2
# Out:
# Collecting pandas==1.3.1
#   Downloading pandas-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 6.6 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.1) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.1) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.1 which is incompatible.
# Successfully installed pandas-1.3.1
# Collecting scipy==1.6.2
#   Downloading scipy-1.6.2-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 1.2 MB/s
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy==1.6.2) (1.19.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.6.2
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.2 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (3.0.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.19.5)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
# Successfully installed scikit-learn-0.24.2

# %%
#import sklearn
#print('The scikit-learn version is {}.'.format(sklearn.__version__))

# %%
import os
import pandas as pd
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
from datetime import date, timedelta
#from isoweek import Week
import math
import warnings; warnings.simplefilter('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

from keras.models import Model
from keras.layers import Input, Dense, Concatenate, Reshape, Dropout
from keras.layers.embeddings import Embedding
from keras.utils.vis_utils import plot_model

from contextlib import redirect_stdout
# %matplotlib inline

# %%
#print(pd.show_versions())

# %% [markdown]
# ## 1.3 Functions<a id='1.3_functions'></a>

# %% [markdown]
# #### 1.3.1 Functions: feature_list <a id='1.3.1_feature_list'></a>

# %%
# organize features in each row into 1) static categorical, 2) temporal categorical, 3) temporal continuous
def feature_list(country_id, row): 
    # Static Categorical
    country = country_id #0 country id
    # Temporal Categorical (datetime variables)
    dt = row[0].to_pydatetime()
    year = dt.year #1
    month = dt.month #2
    day = dt.day #3
    week_of_year = dt.isocalendar()[1] #4
    day_of_week = row[1].dayow #5
    holiday = row[1].holiday #6 holiday
    # Temporal Continuous (mobility variables)
    rtrc = row[1].rtrc #7 retail & recreation
    grph = row[1].grph #8 grocery & pharmacy
    prks = row[1].prks #9 parks
    tran = row[1].tran #10 transportation
    work = row[1].work #11 workplace
    resi = row[1].resi #12 residential area
    # Temporal Continuous (weather variables)
    cloudcover = float(row[1].cloudcover) #13 weather; cloudcover
    tempC = float(row[1].tempC) #14 weather; temparature
    humidity = float(row[1].humidity) #15 weather; humidity
    precipMM = float(row[1].precipMM) #16 weather; precipitation
    # Temporal Continuous (vaccination)
    vac = row[1].vac #17 vaccination
            
    return [country], \
[year, month, day, week_of_year, day_of_week, holiday], \
[rtrc, grph, prks, tran, work, resi, cloudcover, tempC, humidity, precipMM, vac] # Static Categorical, Temporal Categorical, Temporal Continuous

# %% [markdown]
# #### 1.3.2 Functions: ebd_dim <a id='1.3.2_ebd_dim'></a>

# %%
# determine the embedding dimensions
def ebd_dim(cat_dim):
    return min(600, round(1.6 * cat_dim ** .56))

# %% [markdown]
# #### 1.3.3 Functions: split_sequences <a id='1.3.3_split_sequences'></a>

# %%
# get the input and output sequences from the entire time series
def split_sequences(sequences, timestamp, n_steps_in, n_steps_out): 
    timestamps = sequences.index
    df_time0 = timestamps[0]
    df_time_end = timestamps[-1]
    dt_steps_in = timedelta(days=n_steps_in)
    dt_steps_out = timedelta(days=n_steps_out-1)   
    dt_1 = timedelta(days=1)
    if (timestamp-dt_steps_in>=df_time0) & (timestamp+dt_steps_out<=df_time_end): # if within bounds
        # gather input and output parts of the pattern 
        seq_x = sequences[timestamp-dt_steps_in:timestamp-dt_1] # input sequence (e.g. previous 14 days) 
        seq_y = sequences[timestamp:timestamp+dt_steps_out] # output sequence (e.g. next 7 days including the current timestamp)
    return list(seq_x), list(seq_y)

# %% [markdown]
# #### 1.3.4 Functions: to_embed <a id='1.3.4_to_embed'></a>

# %%
# preprocess the embedding columns
def to_embed(cat_columns): 
    
    cat_conv_raw = []
    cat_conv_array = np.empty((cat_columns.shape[0],cat_columns.shape[1]))
    
    for c in range(cat_columns.shape[1]):
        cat_conv_raw.append(list(cat_columns[:,c]))
        raw_vals = np.unique(cat_columns[:,c])
        val_map = {}
        for i in range(len(raw_vals)):
            val_map[raw_vals[i]] = i
        cat_conv_array[:,c] = [val_map[j] for j in cat_conv_raw[c]]
    return cat_conv_array

# %% [markdown]
# #### 1.3.5 Functions: build_MLP_with_embeddings<a id='1.3.5_build_MLP_with_embeddings'></a>

# %%
def build_MLP_with_embeddings(): 
    
    inputs = []
    embeddings = []
    input_dims = []
    
    input_stat_cat_00_country = Input(shape=(1,)) # country (0)
    embedding = Embedding(23, 9, input_length=1)(input_stat_cat_00_country)
    embedding = Reshape(target_shape=(9,))(embedding)
    inputs.append(input_stat_cat_00_country)
    embeddings.append(embedding)
    input_dims.append(input_stat_cat_00_country.shape[-1])
    
    input_temp_cat_01_year = Input(shape=(1,)) # year (1)
    embedding = Embedding(2, 1, input_length=1)(input_temp_cat_01_year)
    embedding = Reshape(target_shape=(1,))(embedding)
    inputs.append(input_temp_cat_01_year)
    embeddings.append(embedding)
    input_dims.append(input_temp_cat_01_year.shape[-1])
     
    input_temp_cat_02_month = Input(shape=(1,)) # month (2)
    embedding = Embedding(12, 6, input_length=1)(input_temp_cat_02_month)
    embedding = Reshape(target_shape=(6,))(embedding)
    inputs.append(input_temp_cat_02_month)
    embeddings.append(embedding)    
    input_dims.append(input_temp_cat_02_month.shape[-1])
    
    input_temp_cat_03_day = Input(shape=(1,)) # day (3)
    embedding = Embedding(31, 11, input_length=1)(input_temp_cat_03_day)
    embedding = Reshape(target_shape=(11,))(embedding)
    inputs.append(input_temp_cat_03_day)
    embeddings.append(embedding)    
    input_dims.append(input_temp_cat_03_day.shape[-1])
    
    input_temp_cat_04_week_of_year = Input(shape=(1,)) # week of year (4)
    embedding = Embedding(53, 15, input_length=1)(input_temp_cat_04_week_of_year)
    embedding = Reshape(target_shape=(15,))(embedding)
    inputs.append(input_temp_cat_04_week_of_year)
    embeddings.append(embedding) 
    input_dims.append(input_temp_cat_04_week_of_year.shape[-1])
    
    input_temp_cat_05_day_of_week = Input(shape=(1,)) # day of week (5)
    embedding = Embedding(7, 5, input_length=1)(input_temp_cat_05_day_of_week)
    embedding = Reshape(target_shape=(5,))(embedding)
    inputs.append(input_temp_cat_05_day_of_week)
    embeddings.append(embedding) 
    input_dims.append(input_temp_cat_05_day_of_week.shape[-1])
    
    input_temp_cat_06_holiday = Input(shape=(1,)) # holiday (6)
    embedding = Embedding(2, 2, input_length=1)(input_temp_cat_06_holiday)
    embedding = Reshape(target_shape=(2,))(embedding)
    inputs.append(input_temp_cat_06_holiday)
    embeddings.append(embedding)  
    input_dims.append(input_temp_cat_06_holiday.shape[-1])
    
    input_numeric = Input(shape=(25,)) # all temporal continuous features (mobility, weather, vaccination)
    dense_numeric = Dense(19)(input_numeric)
    inputs.append(input_numeric)
    embeddings.append(dense_numeric)
    input_dims.append(input_numeric.shape[-1])
    
    x = Concatenate()(embeddings)
    x = Dense(90, activation='relu')(x)
    x = Dropout(.35)(x)
    x = Dense(40, activation='relu')(x)
    x = Dropout(.15)(x)
    x = Dense(10, activation='relu')(x)
    x = Dropout(.15)(x)
    output = Dense(7, activation='linear')(x)
    
    model = Model(inputs, output)
    
    model.compile(loss='binary_crossentropy', optimizer='adam')
    
    return model, input_dims
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# print(model.summary())

# %% [markdown]
# #### 1.3.6 Functions: ndarray_to_input_list <a id='1.3.6_ndarray_to_input_list'></a>

# %%
def ndarray_to_input_list(ndarr,input_dims): 
    input_list = []
    input_dim_cumsum = list(np.cumsum(input_dims))
    input_dim_cumsum.insert(0,0)
    curr_input_0 = input_dim_cumsum[:-1]
    for i,input_0 in enumerate(curr_input_0):
        input_list.append(ndarr[:,input_0:input_0+input_dims[i]])
    return input_list

# %% [markdown]
# #### 1.3.7 Functions: ginic <a id='1.3.7_ginic'></a>

# %%
#gini scoring function from kernel at: 
#https://www.kaggle.com/tezdhar/faster-gini-calculation
def ginic(actual, pred):
    pred_arr = np.asarray(pred)
    if len(pred_arr.shape)==2: # matrix 
        pred_mean = pred.copy()
    elif len(pred_arr.shape)==3: # tuple 
        pred_mean = np.nanmean(pred_arr,axis=0) # average across cross-validation folds
    n, c = actual.shape[0], actual.shape[1]
    gini_sum = []
    for col in range(c):
        a_s = actual[np.argsort(pred_mean[:,col]),col] # returns the indices that would sort an array
        a_c = a_s.cumsum()
        gini_sum.append((a_c.sum() / a_c[-1] - (n + 1) / 2.0)/n) 
    return gini_sum

# %% [markdown]
# #### 1.3.8 Functions: gini_normalizedc <a id='1.3.8_gini_normalizedc'></a>

# %%
def gini_normalizedc(a, p):
    gini_a_p = ginic(a, p)
    gini_a_a = ginic(a, a)
    gini_norm = [gini_a_p[i]/gini_a_a[i] for i in range(len(gini_a_p))]
    return gini_norm

# %% [markdown]
# #### 1.3.9 Functions: rmse_y_y_pred <a id='1.3.9_rmse_y_y_pred'></a>

# %%
def rmse_y_y_pred(rez_dict, n_steps_out):
    rmse_dict = {}
    countries = sorted(set(rez_dict['country']))
    for country in countries:
        country_idx = [cc==country for cc in rez_dict['country']]
        country_rmse = []
        for d in range(n_steps_out):
            country_rmse.append(mean_squared_error(rez_dict['y'][country_idx,d], rez_dict['y_pred'][country_idx,d], squared=False))
        rmse_dict[country] = country_rmse
    return rmse_dict

# %% [markdown]
# #### 1.3.10 Functions: plot_test_set <a id='1.3.10_plot_test_set'></a>

# %%
def plot_test_set(rez_dict, dict_country, save_name, n_steps_out=7):
    countries = sorted(set(rez_dict['country']))
    # plot for each of the 7-day forecast
    for country in countries:
        fig, ax = plt.subplots(n_steps_out, 1, figsize=(12, 36))
        fig.subplots_adjust(wspace=0.5, hspace=0.7)
        
        country_idx = [cc==country for cc in rez_dict['country']]
        timestamps = [i for i,v in zip(rez_dict['timestamp'],country_idx) if v]
        
        holidays = np.array(dict_country[country].loc[timestamps, 'holiday']==1) # holidays
        sundays = np.array(dict_country[country].loc[timestamps, 'dayow']==6) # Sundays
        holi_sun = np.logical_or(holidays, sundays)
        holiday_timestamps = [date.strftime(i, '%b-%d') for i,v in zip(rez_dict['timestamp'],holi_sun) if v]
        
        y_actual = rez_dict['y'][country_idx,:]
        y_pred = rez_dict['y_pred'][country_idx,:]
        
        for i in range(n_steps_out):
            ts_td = [t+timedelta(days=i) for t in timestamps]
            ts = list(map(lambda x:date.strftime(x,'%b-%d'),ts_td))           
            ax[i].plot(ts, y_actual[:,i], 'o-')
            ax[i].plot(ts, y_pred[:,i], 'o-')
            ax[i].set_xlabel('Date', fontsize=10, fontweight='bold')
            ax[i].set_xlim(ts[0], ts[-1])
            ax[i].set_ylabel('Cases per million', fontsize=10, fontweight='bold')          
            ax[i].set_title(country + '_step_#' + str(i), fontweight='bold', fontsize=14)
            ax[i].legend(['y_actual','y_pred'], prop=dict(weight='bold',size=8))
            for tick in ax[i].get_xticklabels():
                tick.set_rotation(45)
            ax[i].tick_params(axis='x', labelsize=8)
            for holi in holiday_timestamps:
                ax[i].axvspan(holi, holi, color='red', alpha=0.3, linewidth=2)
        # figure save
        fig.savefig(os.path.join('/content/drive/My Drive/Colab_data/covid19/Figure', \
                                 country+'_'+save_name+'_MLP_7d.pdf'), tranparent=True)

# %% [markdown]
# ## 1.4 Load data<a id='1.4_load_data'></a>

# %%
# load data from pickle file
filePath_pickle = Path('/content/drive/My Drive/Colab_data/covid19/covid_country_data.pickle')
with open(filePath_pickle, 'rb') as f:
    dict_country = pd.read_pickle(f)
# countries = ['AR', 'AT', 'AU', 'BE', 'CA', 'DE', 'DK', 'FI', 'FR', 'GB', 'ID', 'IE', 'IL', 'IN', 'IT', 'JP', 'KR', 'MX', 'NL', 'NO', 'RU', 'SG', 'US']

# %% [markdown]
# ## 1.5 Preprocessing <a id='1.5_Preprocessing'></a>

# %% [markdown]
# #### 1.5.1 Preprocessing: get feature and target for model training and testing with cross-validation <a id='1.5.1_get_feature_target'></a>

# %%
train_timestamp = []
train_country = []
train_stat_cat = []
train_temp_cat = []
train_temp_con = []
train_feature_case = []
train_y_unscaled = []
test_timestamp = []
test_country = []
test_stat_cat = []
test_temp_cat = []
test_temp_con = []
test_feature_case = []
test_y_unscaled = []

n_test = 21 # days
dt_test = timedelta(days=n_test-1)
n_steps_in = 14 # days (# previous cases)
dt_steps_in = timedelta(days=n_steps_in)
n_steps_out = 7 # days (# future cases to be predicted)
dt_steps_out = timedelta(days=n_steps_out-1)

for i, country_key in enumerate(dict_country.keys()):
    case_detection = 0
    df_country = dict_country[country_key]
    df_country.fillna(method='ffill',inplace=True) # forward fill NaNs
    df_time0 = df_country.index[0] # the first day of the data
    df_time_end = df_country.index[-1] # the last day of the data
    # split the df into train and test sets
    test_time0 = df_country.index[-1]-dt_test # the first date of test set 
    train_ind = df_country.index < test_time0 # training index
    # feature_list train 
    df_country_train = df_country.loc[train_ind] # train df
    for row in df_country_train.iterrows():
        ts_curr = row[0] 
        # case_mil lagging
        if (ts_curr-dt_steps_in>=df_time0) & (ts_curr+dt_steps_out<=df_time_end):
            # get feature and target variables
            feature_case, target_case = split_sequences(df_country['case_mil'], ts_curr, n_steps_in, n_steps_out)         
            if (case_detection == 0) & (sum(feature_case)>0): # to exclude days before 1st case detection
                case_detection = 1
            if case_detection == 1:
                fl_stat_cat, fl_temp_cat, fl_temp_con = feature_list(i, row) # get static categorical, temporal categorical, temporal continuous variables separately 
                # train data X
                train_country.append(row[1].country_region_code)
                train_timestamp.append(ts_curr) # timestamps
                train_stat_cat.append(fl_stat_cat) # static categorical 
                train_temp_cat.append(fl_temp_cat) # temporal categorical 
                train_temp_con.append(fl_temp_con) # temporal continuous
                train_feature_case.append(feature_case) # case_mil previous days to be used as features
                # train data y
                train_y_unscaled.append(target_case) # case_mil current & future days to be predicted
    # feature list test
    df_country_test = df_country.loc[~train_ind] # test df
    # feature list test 
    for row in df_country_test.iterrows():
        ts_curr = row[0]
        # case_mil lagging
        if (ts_curr-dt_steps_in>=df_time0) & (ts_curr+dt_steps_out<=df_time_end):        
            # get feature and target variables
            feature_case, target_case = split_sequences(df_country['case_mil'], ts_curr, n_steps_in, n_steps_out) 
            fl_stat_cat, fl_temp_cat, fl_temp_con = feature_list(i, row) # get static categorical, temporal categorical, temporal continuous variables separately
            # test data X
            test_country.append(row[1].country_region_code)
            test_timestamp.append(ts_curr)
            test_stat_cat.append(fl_stat_cat) # static categorical 
            test_temp_cat.append(fl_temp_cat) # temporal categorical 
            test_temp_con.append(fl_temp_con) # temporal continuous
            test_feature_case.append(feature_case) # case_mil previous days to be used as features
            # train data y
            test_y_unscaled.append(target_case) # case_mil current & future days to be predicted

# %% [markdown]
# #### 1.5.2 Preprocessing: scale feature and target variables <a id='1.5.2_scale_feature_target'></a>

# %%
# convert list to ndarray
train_stat_cat_embed = to_embed(np.array(train_stat_cat))
train_temp_cat_embed = to_embed(np.array(train_temp_cat))
train_temp_con = np.array(train_temp_con)
train_feature_case = np.reshape(train_feature_case, (len(train_timestamp), n_steps_in))
train_y_unscaled = np.reshape(train_y_unscaled, (len(train_timestamp), n_steps_out))
test_stat_cat_embed = to_embed(np.array(test_stat_cat))
test_temp_cat_embed = to_embed(np.array(test_temp_cat))
test_temp_con = np.array(test_temp_con)
test_feature_case = np.reshape(test_feature_case, (len(test_timestamp), n_steps_in))
test_y_unscaled = np.reshape(test_y_unscaled, (len(test_timestamp), n_steps_out))
# scale the temporal continuous variables
temp_con_scaler = MinMaxScaler()
temp_con_scaler.fit(train_temp_con)
train_temp_con_scaled = temp_con_scaler.transform(train_temp_con)
test_temp_con_scaled = temp_con_scaler.transform(test_temp_con)
# scale feature and target cases (case_mil)
scaler_feature_case = StandardScaler()
scaler_y = StandardScaler()
case_all_1d = np.concatenate((train_feature_case.reshape(-1,1), test_feature_case.reshape(-1,1),\
                            train_y_unscaled.reshape(-1,1), test_y_unscaled.reshape(-1,1)),axis=0)
y_all_feature = np.matlib.repmat(case_all_1d, 1, train_feature_case.shape[1])
y_all_test = np.matlib.repmat(case_all_1d, 1, train_y_unscaled.shape[1])

scaler_feature_case.fit(y_all_feature)
scaler_y.fit(y_all_test)

train_feature_case_scaled = scaler_feature_case.transform(train_feature_case)
test_feature_case_scaled = scaler_feature_case.transform(test_feature_case)

train_y = scaler_y.transform(train_y_unscaled)
test_y = scaler_y.transform(test_y_unscaled)
# concatenate
train_X = np.concatenate((train_stat_cat_embed, train_temp_cat_embed, train_temp_con_scaled, train_feature_case_scaled), axis=1)
test_X = np.concatenate((test_stat_cat_embed, test_temp_cat_embed, test_temp_con_scaled, test_feature_case_scaled), axis=1)
print("Number of train datapoints: ", len(train_y))
print("Number of test datapoints: ", len(test_y))
# Out:
# Number of train datapoints:  12541
# Number of test datapoints:  345

# %% [markdown]
# ## 1.6 Train and test the MLP model <a id='1.6_train_test_model'></a>

# %% [markdown]
# #### 1.6.1 Train and test the MLP model: train and test with cross-validation <a id='1.6.1_train_test_crossvalidation'></a>

# %%
# get the cross-validation folds for train and validation sets  
train_folds = []
validation_folds = []
# get the timestamps for train and validation folds
sorted_train_timestamp = sorted((set(train_timestamp))) # unique timestamps in the train set
tscv = TimeSeriesSplit(n_splits=5, test_size=20) # splitting train and validations sets for cross validation
for train_idx, validation_idx in tscv.split(sorted_train_timestamp): # get train and validation sets
    # print("TRAIN:", train_idx, "VALIDATION:", validation_idx)
    train_folds.append([sorted_train_timestamp[i] for i in train_idx]) # folds in train set
    validation_folds.append([sorted_train_timestamp[i] for i in validation_idx]) # folds in validation set

n_epochs = 1000
runs_per_fold = 20

cv_ginis = []
train_preds = []
train_idx_fold = [] 
val_preds = []
val_idx_fold = []
test_preds = []

# network training
for fold in range(len(train_folds)): # iterate cross-validation folds
    fold_idx_train = [ts in train_folds[fold] for ts in train_timestamp]
    train_idx_fold.append(fold_idx_train)
    fold_idx_val = [ts in validation_folds[fold] for ts in train_timestamp]
    val_idx_fold.append(fold_idx_val)
    X_train_f, X_val_f = train_X[fold_idx_train,:], train_X[fold_idx_val,:] # X_train for the current fold
    y_train_f, y_val_f = train_y[fold_idx_train,:], train_y[fold_idx_val,:] # y_train for the current fold
    
    train_preds_fold = []
    val_preds_fold = []
    
    for run_n in range(runs_per_fold): # iterate # of runs per fold
        # build the model
        NN, input_dim_NN = build_MLP_with_embeddings() # build the model and get input dimensions
        
        X_train_f_input = ndarray_to_input_list(X_train_f, input_dim_NN)
        X_val_f_input = ndarray_to_input_list(X_val_f, input_dim_NN)
        X_test_f_input = ndarray_to_input_list(test_X, input_dim_NN)
        
        NN.fit(X_train_f_input, y_train_f, epochs=n_epochs, batch_size=2048, verbose=2)
   
        train_preds_fold.append(NN.predict(X_train_f_input))
        val_preds_fold.append(NN.predict(X_val_f_input))
        test_preds.append(NN.predict(X_test_f_input))
    
    cv_gini = gini_normalizedc(y_val_f, val_preds_fold) # actual, predicted
    cv_ginis.append(cv_gini)
    for i, cvg in enumerate(cv_gini):
        print('\nFold %d prediction cv gini_%d: %.5f\n' %(fold,i,cv_gini[i]))
    
    train_preds.append(np.mean(np.asarray(train_preds_fold),axis=0)) # ave
    val_preds.append(np.mean(np.asarray(val_preds_fold),axis=0))
    
cv_gini_mean = np.nanmean(np.asarray(cv_ginis),axis=0)
for i, g in enumerate(cv_gini_mean):
    print('Mean validation fold gini_%d: %.5f\n' %(i,g))

test_y_pred = np.nanmean(np.asarray(test_preds),axis=0) # average across cross-validation folds and runs
# Out:
# Streaming output truncated to the last 5000 lines.
# 6/6 - 0s - loss: -6.6077e+00 - 34ms/epoch - 6ms/step
# Epoch 519/1000
# 6/6 - 0s - loss: -6.5992e+00 - 35ms/epoch - 6ms/step
# Epoch 520/1000
# 6/6 - 0s - loss: -6.5863e+00 - 35ms/epoch - 6ms/step
# Epoch 521/1000
# 6/6 - 0s - loss: -6.6102e+00 - 35ms/epoch - 6ms/step
# Epoch 522/1000
# 6/6 - 0s - loss: -6.6156e+00 - 33ms/epoch - 6ms/step
# Epoch 523/1000
# 6/6 - 0s - loss: -6.5989e+00 - 34ms/epoch - 6ms/step
# Epoch 524/1000
# 6/6 - 0s - loss: -6.5549e+00 - 33ms/epoch - 5ms/step
# Epoch 525/1000
# 6/6 - 0s - loss: -6.5005e+00 - 35ms/epoch - 6ms/step
# Epoch 526/1000
# 6/6 - 0s - loss: -6.5278e+00 - 35ms/epoch - 6ms/step
# Epoch 527/1000
# 6/6 - 0s - loss: -6.5264e+00 - 33ms/epoch - 5ms/step
# Epoch 528/1000
# 6/6 - 0s - loss: -6.5290e+00 - 33ms/epoch - 5ms/step
# Epoch 529/1000
# 6/6 - 0s - loss: -6.5456e+00 - 35ms/epoch - 6ms/step
# Epoch 530/1000
# 6/6 - 0s - loss: -6.5579e+00 - 37ms/epoch - 6ms/step
# Epoch 531/1000
# 6/6 - 0s - loss: -6.5775e+00 - 34ms/epoch - 6ms/step
# Epoch 532/1000
# 6/6 - 0s - loss: -6.5842e+00 - 35ms/epoch - 6ms/step
# Epoch 533/1000
# 6/6 - 0s - loss: -6.6044e+00 - 33ms/epoch - 6ms/step
# Epoch 534/1000
# 6/6 - 0s - loss: -6.5949e+00 - 33ms/epoch - 6ms/step
# Epoch 535/1000
# 6/6 - 0s - loss: -6.5967e+00 - 36ms/epoch - 6ms/step
# Epoch 536/1000
# 6/6 - 0s - loss: -6.5869e+00 - 32ms/epoch - 5ms/step
# Epoch 537/1000
# 6/6 - 0s - loss: -6.6034e+00 - 31ms/epoch - 5ms/step
# Epoch 538/1000
# 6/6 - 0s - loss: -6.5860e+00 - 34ms/epoch - 6ms/step
# Epoch 539/1000
# 6/6 - 0s - loss: -6.5874e+00 - 35ms/epoch - 6ms/step
# Epoch 540/1000
# 6/6 - 0s - loss: -6.5831e+00 - 34ms/epoch - 6ms/step
# Epoch 541/1000
# 6/6 - 0s - loss: -6.5617e+00 - 33ms/epoch - 5ms/step
# Epoch 542/1000
# 6/6 - 0s - loss: -6.5818e+00 - 35ms/epoch - 6ms/step
# Epoch 543/1000
# 6/6 - 0s - loss: -6.6020e+00 - 34ms/epoch - 6ms/step
# Epoch 544/1000
# 6/6 - 0s - loss: -6.5966e+00 - 34ms/epoch - 6ms/step
# Epoch 545/1000
# 6/6 - 0s - loss: -6.6178e+00 - 34ms/epoch - 6ms/step
# Epoch 546/1000
# 6/6 - 0s - loss: -6.6140e+00 - 34ms/epoch - 6ms/step
# Epoch 547/1000
# 6/6 - 0s - loss: -6.6141e+00 - 36ms/epoch - 6ms/step
# Epoch 548/1000
# 6/6 - 0s - loss: -6.6122e+00 - 33ms/epoch - 5ms/step
# Epoch 549/1000
# 6/6 - 0s - loss: -6.6158e+00 - 31ms/epoch - 5ms/step
# Epoch 550/1000
# 6/6 - 0s - loss: -6.6207e+00 - 35ms/epoch - 6ms/step
# Epoch 551/1000
# 6/6 - 0s - loss: -6.6218e+00 - 34ms/epoch - 6ms/step
# Epoch 552/1000
# 6/6 - 0s - loss: -6.6386e+00 - 34ms/epoch - 6ms/step
# Epoch 553/1000
# 6/6 - 0s - loss: -6.6047e+00 - 32ms/epoch - 5ms/step
# Epoch 554/1000
# 6/6 - 0s - loss: -6.6152e+00 - 35ms/epoch - 6ms/step
# Epoch 555/1000
# 6/6 - 0s - loss: -6.6113e+00 - 33ms/epoch - 6ms/step
# Epoch 556/1000
# 6/6 - 0s - loss: -6.6226e+00 - 34ms/epoch - 6ms/step
# Epoch 557/1000
# 6/6 - 0s - loss: -6.5563e+00 - 34ms/epoch - 6ms/step
# Epoch 558/1000
# 6/6 - 0s - loss: -6.6236e+00 - 35ms/epoch - 6ms/step
# Epoch 559/1000
# 6/6 - 0s - loss: -6.6128e+00 - 34ms/epoch - 6ms/step
# Epoch 560/1000
# 6/6 - 0s - loss: -6.6235e+00 - 32ms/epoch - 5ms/step
# Epoch 561/1000
# 6/6 - 0s - loss: -6.6088e+00 - 31ms/epoch - 5ms/step
# Epoch 562/1000
# 6/6 - 0s - loss: -6.6114e+00 - 35ms/epoch - 6ms/step
# Epoch 563/1000
# 6/6 - 0s - loss: -6.6207e+00 - 35ms/epoch - 6ms/step
# Epoch 564/1000
# 6/6 - 0s - loss: -6.5997e+00 - 32ms/epoch - 5ms/step
# Epoch 565/1000
# 6/6 - 0s - loss: -6.6317e+00 - 33ms/epoch - 5ms/step
# Epoch 566/1000
# 6/6 - 0s - loss: -6.6117e+00 - 34ms/epoch - 6ms/step
# Epoch 567/1000
# 6/6 - 0s - loss: -6.6346e+00 - 35ms/epoch - 6ms/step
# Epoch 568/1000
# 6/6 - 0s - loss: -6.6171e+00 - 38ms/epoch - 6ms/step
# Epoch 569/1000
# 6/6 - 0s - loss: -6.6262e+00 - 35ms/epoch - 6ms/step
# Epoch 570/1000
# 6/6 - 0s - loss: -6.6218e+00 - 32ms/epoch - 5ms/step
# Epoch 571/1000
# 6/6 - 0s - loss: -6.6383e+00 - 34ms/epoch - 6ms/step
# Epoch 572/1000
# 6/6 - 0s - loss: -6.6232e+00 - 32ms/epoch - 5ms/step
# Epoch 573/1000
# 6/6 - 0s - loss: -6.6270e+00 - 33ms/epoch - 5ms/step
# Epoch 574/1000
# 6/6 - 0s - loss: -6.6244e+00 - 32ms/epoch - 5ms/step
# Epoch 575/1000
# 6/6 - 0s - loss: -6.6327e+00 - 30ms/epoch - 5ms/step
# Epoch 576/1000
# 6/6 - 0s - loss: -6.6299e+00 - 31ms/epoch - 5ms/step
# Epoch 577/1000
# 6/6 - 0s - loss: -6.6436e+00 - 32ms/epoch - 5ms/step
# Epoch 578/1000
# 6/6 - 0s - loss: -6.6285e+00 - 33ms/epoch - 6ms/step
# Epoch 579/1000
# 6/6 - 0s - loss: -6.6297e+00 - 29ms/epoch - 5ms/step
# Epoch 580/1000
# 6/6 - 0s - loss: -6.6259e+00 - 36ms/epoch - 6ms/step
# Epoch 581/1000
# 6/6 - 0s - loss: -6.6269e+00 - 34ms/epoch - 6ms/step
# Epoch 582/1000
# 6/6 - 0s - loss: -6.6458e+00 - 34ms/epoch - 6ms/step
# Epoch 583/1000
# 6/6 - 0s - loss: -6.6324e+00 - 35ms/epoch - 6ms/step
# Epoch 584/1000
# 6/6 - 0s - loss: -6.6382e+00 - 34ms/epoch - 6ms/step
# Epoch 585/1000
# 6/6 - 0s - loss: -6.6325e+00 - 34ms/epoch - 6ms/step
# Epoch 586/1000
# 6/6 - 0s - loss: -6.6390e+00 - 34ms/epoch - 6ms/step
# Epoch 587/1000
# 6/6 - 0s - loss: -6.6297e+00 - 35ms/epoch - 6ms/step
# Epoch 588/1000
# 6/6 - 0s - loss: -6.6369e+00 - 33ms/epoch - 5ms/step
# Epoch 589/1000
# 6/6 - 0s - loss: -6.6313e+00 - 32ms/epoch - 5ms/step
# Epoch 590/1000
# 6/6 - 0s - loss: -6.6317e+00 - 33ms/epoch - 6ms/step
# Epoch 591/1000
# 6/6 - 0s - loss: -6.6186e+00 - 34ms/epoch - 6ms/step
# Epoch 592/1000
# 6/6 - 0s - loss: -6.6194e+00 - 33ms/epoch - 6ms/step
# Epoch 593/1000
# 6/6 - 0s - loss: -6.6373e+00 - 31ms/epoch - 5ms/step
# Epoch 594/1000
# 6/6 - 0s - loss: -6.6304e+00 - 34ms/epoch - 6ms/step
# Epoch 595/1000
# 6/6 - 0s - loss: -6.6443e+00 - 32ms/epoch - 5ms/step
# Epoch 596/1000
# 6/6 - 0s - loss: -6.6548e+00 - 31ms/epoch - 5ms/step
# Epoch 597/1000
# 6/6 - 0s - loss: -6.6428e+00 - 34ms/epoch - 6ms/step
# Epoch 598/1000
# 6/6 - 0s - loss: -6.6418e+00 - 34ms/epoch - 6ms/step
# Epoch 599/1000
# 6/6 - 0s - loss: -6.6390e+00 - 33ms/epoch - 5ms/step
# Epoch 600/1000
# 6/6 - 0s - loss: -6.6404e+00 - 33ms/epoch - 6ms/step
# Epoch 601/1000
# 6/6 - 0s - loss: -6.6187e+00 - 34ms/epoch - 6ms/step
# Epoch 602/1000
# 6/6 - 0s - loss: -6.6369e+00 - 30ms/epoch - 5ms/step
# Epoch 603/1000
# 6/6 - 0s - loss: -6.6319e+00 - 34ms/epoch - 6ms/step
# Epoch 604/1000
# 6/6 - 0s - loss: -6.6271e+00 - 33ms/epoch - 5ms/step
# Epoch 605/1000
# 6/6 - 0s - loss: -6.6418e+00 - 33ms/epoch - 5ms/step
# Epoch 606/1000
# 6/6 - 0s - loss: -6.6310e+00 - 32ms/epoch - 5ms/step
# Epoch 607/1000
# 6/6 - 0s - loss: -6.6526e+00 - 35ms/epoch - 6ms/step
# Epoch 608/1000
# 6/6 - 0s - loss: -6.6576e+00 - 34ms/epoch - 6ms/step
# Epoch 609/1000
# 6/6 - 0s - loss: -6.6541e+00 - 31ms/epoch - 5ms/step
# Epoch 610/1000
# 6/6 - 0s - loss: -6.6512e+00 - 34ms/epoch - 6ms/step
# Epoch 611/1000
# 6/6 - 0s - loss: -6.6560e+00 - 31ms/epoch - 5ms/step
# Epoch 612/1000
# 6/6 - 0s - loss: -6.6410e+00 - 33ms/epoch - 5ms/step
# Epoch 613/1000
# 6/6 - 0s - loss: -6.6500e+00 - 33ms/epoch - 6ms/step
# Epoch 614/1000
# 6/6 - 0s - loss: -6.6451e+00 - 33ms/epoch - 5ms/step
# Epoch 615/1000
# 6/6 - 0s - loss: -6.6453e+00 - 35ms/epoch - 6ms/step
# Epoch 616/1000
# 6/6 - 0s - loss: -6.6470e+00 - 33ms/epoch - 5ms/step
# Epoch 617/1000
# 6/6 - 0s - loss: -6.5871e+00 - 33ms/epoch - 5ms/step
# Epoch 618/1000
# 6/6 - 0s - loss: -6.6546e+00 - 32ms/epoch - 5ms/step
# Epoch 619/1000
# 6/6 - 0s - loss: -6.6439e+00 - 32ms/epoch - 5ms/step
# Epoch 620/1000
# 6/6 - 0s - loss: -6.6531e+00 - 34ms/epoch - 6ms/step
# Epoch 621/1000
# 6/6 - 0s - loss: -6.6477e+00 - 32ms/epoch - 5ms/step
# Epoch 622/1000
# 6/6 - 0s - loss: -6.5838e+00 - 32ms/epoch - 5ms/step
# Epoch 623/1000
# 6/6 - 0s - loss: -6.6450e+00 - 35ms/epoch - 6ms/step
# Epoch 624/1000
# 6/6 - 0s - loss: -6.6540e+00 - 32ms/epoch - 5ms/step
# Epoch 625/1000
# 6/6 - 0s - loss: -6.6459e+00 - 33ms/epoch - 5ms/step
# Epoch 626/1000
# 6/6 - 0s - loss: -6.6461e+00 - 32ms/epoch - 5ms/step
# Epoch 627/1000
# 6/6 - 0s - loss: -6.6379e+00 - 36ms/epoch - 6ms/step
# Epoch 628/1000
# 6/6 - 0s - loss: -6.6630e+00 - 33ms/epoch - 6ms/step
# Epoch 629/1000
# 6/6 - 0s - loss: -6.6620e+00 - 32ms/epoch - 5ms/step
# Epoch 630/1000
# 6/6 - 0s - loss: -6.6558e+00 - 34ms/epoch - 6ms/step
# Epoch 631/1000
# 6/6 - 0s - loss: -6.6463e+00 - 38ms/epoch - 6ms/step
# Epoch 632/1000
# 6/6 - 0s - loss: -6.6412e+00 - 34ms/epoch - 6ms/step
# Epoch 633/1000
# 6/6 - 0s - loss: -6.6554e+00 - 32ms/epoch - 5ms/step
# Epoch 634/1000
# 6/6 - 0s - loss: -6.6512e+00 - 33ms/epoch - 5ms/step
# Epoch 635/1000
# 6/6 - 0s - loss: -6.6606e+00 - 35ms/epoch - 6ms/step
# Epoch 636/1000
# 6/6 - 0s - loss: -6.6384e+00 - 34ms/epoch - 6ms/step
# Epoch 637/1000
# 6/6 - 0s - loss: -6.6344e+00 - 35ms/epoch - 6ms/step
# Epoch 638/1000
# 6/6 - 0s - loss: -6.6221e+00 - 34ms/epoch - 6ms/step
# Epoch 639/1000
# 6/6 - 0s - loss: -6.6255e+00 - 35ms/epoch - 6ms/step
# Epoch 640/1000
# 6/6 - 0s - loss: -6.6207e+00 - 33ms/epoch - 6ms/step
# Epoch 641/1000
# 6/6 - 0s - loss: -6.6156e+00 - 33ms/epoch - 5ms/step
# Epoch 642/1000
# 6/6 - 0s - loss: -6.6230e+00 - 33ms/epoch - 6ms/step
# Epoch 643/1000
# 6/6 - 0s - loss: -6.6291e+00 - 34ms/epoch - 6ms/step
# Epoch 644/1000
# 6/6 - 0s - loss: -6.6280e+00 - 35ms/epoch - 6ms/step
# Epoch 645/1000
# 6/6 - 0s - loss: -6.6294e+00 - 33ms/epoch - 5ms/step
# Epoch 646/1000
# 6/6 - 0s - loss: -6.6354e+00 - 34ms/epoch - 6ms/step
# Epoch 647/1000
# 6/6 - 0s - loss: -6.6370e+00 - 38ms/epoch - 6ms/step
# Epoch 648/1000
# 6/6 - 0s - loss: -6.6313e+00 - 41ms/epoch - 7ms/step
# Epoch 649/1000
# 6/6 - 0s - loss: -6.6482e+00 - 39ms/epoch - 7ms/step
# Epoch 650/1000
# 6/6 - 0s - loss: -6.6536e+00 - 35ms/epoch - 6ms/step
# Epoch 651/1000
# 6/6 - 0s - loss: -6.6475e+00 - 36ms/epoch - 6ms/step
# Epoch 652/1000
# 6/6 - 0s - loss: -6.6529e+00 - 35ms/epoch - 6ms/step
# Epoch 653/1000
# 6/6 - 0s - loss: -6.6594e+00 - 39ms/epoch - 7ms/step
# Epoch 654/1000
# 6/6 - 0s - loss: -6.6330e+00 - 37ms/epoch - 6ms/step
# Epoch 655/1000
# 6/6 - 0s - loss: -6.5675e+00 - 36ms/epoch - 6ms/step
# Epoch 656/1000
# 6/6 - 0s - loss: -6.5794e+00 - 38ms/epoch - 6ms/step
# Epoch 657/1000
# 6/6 - 0s - loss: -6.6042e+00 - 40ms/epoch - 7ms/step
# Epoch 658/1000
# 6/6 - 0s - loss: -6.6565e+00 - 34ms/epoch - 6ms/step
# Epoch 659/1000
# 6/6 - 0s - loss: -6.6563e+00 - 34ms/epoch - 6ms/step
# Epoch 660/1000
# 6/6 - 0s - loss: -6.6377e+00 - 34ms/epoch - 6ms/step
# Epoch 661/1000
# 6/6 - 0s - loss: -6.6513e+00 - 37ms/epoch - 6ms/step
# Epoch 662/1000
# 6/6 - 0s - loss: -6.6526e+00 - 34ms/epoch - 6ms/step
# Epoch 663/1000
# 6/6 - 0s - loss: -6.6564e+00 - 33ms/epoch - 6ms/step
# Epoch 664/1000
# 6/6 - 0s - loss: -6.6510e+00 - 32ms/epoch - 5ms/step
# Epoch 665/1000
# 6/6 - 0s - loss: -6.6560e+00 - 34ms/epoch - 6ms/step
# Epoch 666/1000
# 6/6 - 0s - loss: -6.6535e+00 - 34ms/epoch - 6ms/step
# Epoch 667/1000
# 6/6 - 0s - loss: -6.6466e+00 - 35ms/epoch - 6ms/step
# Epoch 668/1000
# 6/6 - 0s - loss: -6.6458e+00 - 32ms/epoch - 5ms/step
# Epoch 669/1000
# 6/6 - 0s - loss: -6.6234e+00 - 34ms/epoch - 6ms/step
# Epoch 670/1000
# 6/6 - 0s - loss: -6.6354e+00 - 32ms/epoch - 5ms/step
# Epoch 671/1000
# 6/6 - 0s - loss: -6.6425e+00 - 31ms/epoch - 5ms/step
# Epoch 672/1000
# 6/6 - 0s - loss: -6.6443e+00 - 38ms/epoch - 6ms/step
# Epoch 673/1000
# 6/6 - 0s - loss: -6.6507e+00 - 32ms/epoch - 5ms/step
# Epoch 674/1000
# 6/6 - 0s - loss: -6.6562e+00 - 34ms/epoch - 6ms/step
# Epoch 675/1000
# 6/6 - 0s - loss: -6.6528e+00 - 31ms/epoch - 5ms/step
# Epoch 676/1000
# 6/6 - 0s - loss: -6.6389e+00 - 32ms/epoch - 5ms/step
# Epoch 677/1000
# 6/6 - 0s - loss: -6.6447e+00 - 33ms/epoch - 6ms/step
# Epoch 678/1000
# 6/6 - 0s - loss: -6.6546e+00 - 32ms/epoch - 5ms/step
# Epoch 679/1000
# 6/6 - 0s - loss: -6.6452e+00 - 36ms/epoch - 6ms/step
# Epoch 680/1000
# 6/6 - 0s - loss: -6.6542e+00 - 31ms/epoch - 5ms/step
# Epoch 681/1000
# 6/6 - 0s - loss: -6.6463e+00 - 35ms/epoch - 6ms/step
# Epoch 682/1000
# 6/6 - 0s - loss: -6.6466e+00 - 36ms/epoch - 6ms/step
# Epoch 683/1000
# 6/6 - 0s - loss: -6.6674e+00 - 34ms/epoch - 6ms/step
# Epoch 684/1000
# 6/6 - 0s - loss: -6.6559e+00 - 32ms/epoch - 5ms/step
# Epoch 685/1000
# 6/6 - 0s - loss: -6.6416e+00 - 31ms/epoch - 5ms/step
# Epoch 686/1000
# 6/6 - 0s - loss: -6.6592e+00 - 34ms/epoch - 6ms/step
# Epoch 687/1000
# 6/6 - 0s - loss: -6.6625e+00 - 34ms/epoch - 6ms/step
# Epoch 688/1000
# 6/6 - 0s - loss: -6.6659e+00 - 34ms/epoch - 6ms/step
# Epoch 689/1000
# 6/6 - 0s - loss: -6.6408e+00 - 33ms/epoch - 5ms/step
# Epoch 690/1000
# 6/6 - 0s - loss: -6.6726e+00 - 32ms/epoch - 5ms/step
# Epoch 691/1000
# 6/6 - 0s - loss: -6.6574e+00 - 33ms/epoch - 5ms/step
# Epoch 692/1000
# 6/6 - 0s - loss: -6.6602e+00 - 33ms/epoch - 6ms/step
# Epoch 693/1000
# 6/6 - 0s - loss: -6.6663e+00 - 31ms/epoch - 5ms/step
# Epoch 694/1000
# 6/6 - 0s - loss: -6.6514e+00 - 33ms/epoch - 6ms/step
# Epoch 695/1000
# 6/6 - 0s - loss: -6.5792e+00 - 35ms/epoch - 6ms/step
# Epoch 696/1000
# 6/6 - 0s - loss: -6.3553e+00 - 34ms/epoch - 6ms/step
# Epoch 697/1000
# 6/6 - 0s - loss: -6.3202e+00 - 34ms/epoch - 6ms/step
# Epoch 698/1000
# 6/6 - 0s - loss: -6.3661e+00 - 36ms/epoch - 6ms/step
# Epoch 699/1000
# 6/6 - 0s - loss: -6.4268e+00 - 38ms/epoch - 6ms/step
# Epoch 700/1000
# 6/6 - 0s - loss: -6.4665e+00 - 36ms/epoch - 6ms/step
# Epoch 701/1000
# 6/6 - 0s - loss: -6.5112e+00 - 33ms/epoch - 6ms/step
# Epoch 702/1000
# 6/6 - 0s - loss: -6.5505e+00 - 32ms/epoch - 5ms/step
# Epoch 703/1000
# 6/6 - 0s - loss: -6.5648e+00 - 34ms/epoch - 6ms/step
# Epoch 704/1000
# 6/6 - 0s - loss: -6.6081e+00 - 34ms/epoch - 6ms/step
# Epoch 705/1000
# 6/6 - 0s - loss: -6.6026e+00 - 31ms/epoch - 5ms/step
# Epoch 706/1000
# 6/6 - 0s - loss: -6.6054e+00 - 32ms/epoch - 5ms/step
# Epoch 707/1000
# 6/6 - 0s - loss: -6.6234e+00 - 34ms/epoch - 6ms/step
# Epoch 708/1000
# 6/6 - 0s - loss: -6.6284e+00 - 34ms/epoch - 6ms/step
# Epoch 709/1000
# 6/6 - 0s - loss: -6.6197e+00 - 34ms/epoch - 6ms/step
# Epoch 710/1000
# 6/6 - 0s - loss: -6.6350e+00 - 32ms/epoch - 5ms/step
# Epoch 711/1000
# 6/6 - 0s - loss: -6.6061e+00 - 31ms/epoch - 5ms/step
# Epoch 712/1000
# 6/6 - 0s - loss: -6.6349e+00 - 34ms/epoch - 6ms/step
# Epoch 713/1000
# 6/6 - 0s - loss: -6.6319e+00 - 35ms/epoch - 6ms/step
# Epoch 714/1000
# 6/6 - 0s - loss: -6.6361e+00 - 33ms/epoch - 5ms/step
# Epoch 715/1000
# 6/6 - 0s - loss: -6.6366e+00 - 31ms/epoch - 5ms/step
# Epoch 716/1000
# 6/6 - 0s - loss: -6.6230e+00 - 31ms/epoch - 5ms/step
# Epoch 717/1000
# 6/6 - 0s - loss: -6.6231e+00 - 36ms/epoch - 6ms/step
# Epoch 718/1000
# 6/6 - 0s - loss: -6.6274e+00 - 32ms/epoch - 5ms/step
# Epoch 719/1000
# 6/6 - 0s - loss: -6.6180e+00 - 32ms/epoch - 5ms/step
# Epoch 720/1000
# 6/6 - 0s - loss: -6.6183e+00 - 35ms/epoch - 6ms/step
# Epoch 721/1000
# 6/6 - 0s - loss: -6.6121e+00 - 37ms/epoch - 6ms/step
# Epoch 722/1000
# 6/6 - 0s - loss: -6.6095e+00 - 32ms/epoch - 5ms/step
# Epoch 723/1000
# 6/6 - 0s - loss: -6.6146e+00 - 34ms/epoch - 6ms/step
# Epoch 724/1000
# 6/6 - 0s - loss: -6.6205e+00 - 36ms/epoch - 6ms/step
# Epoch 725/1000
# 6/6 - 0s - loss: -6.6286e+00 - 34ms/epoch - 6ms/step
# Epoch 726/1000
# 6/6 - 0s - loss: -6.6323e+00 - 32ms/epoch - 5ms/step
# Epoch 727/1000
# 6/6 - 0s - loss: -6.6332e+00 - 33ms/epoch - 6ms/step
# Epoch 728/1000
# 6/6 - 0s - loss: -6.6339e+00 - 33ms/epoch - 5ms/step
# Epoch 729/1000
# 6/6 - 0s - loss: -6.6582e+00 - 32ms/epoch - 5ms/step
# Epoch 730/1000
# 6/6 - 0s - loss: -6.6234e+00 - 32ms/epoch - 5ms/step
# Epoch 731/1000
# 6/6 - 0s - loss: -6.6423e+00 - 33ms/epoch - 5ms/step
# Epoch 732/1000
# 6/6 - 0s - loss: -6.6387e+00 - 32ms/epoch - 5ms/step
# Epoch 733/1000
# 6/6 - 0s - loss: -6.6424e+00 - 36ms/epoch - 6ms/step
# Epoch 734/1000
# 6/6 - 0s - loss: -6.6414e+00 - 34ms/epoch - 6ms/step
# Epoch 735/1000
# 6/6 - 0s - loss: -6.6364e+00 - 32ms/epoch - 5ms/step
# Epoch 736/1000
# 6/6 - 0s - loss: -6.6624e+00 - 33ms/epoch - 5ms/step
# Epoch 737/1000
# 6/6 - 0s - loss: -6.6393e+00 - 33ms/epoch - 5ms/step
# Epoch 738/1000
# 6/6 - 0s - loss: -6.6530e+00 - 32ms/epoch - 5ms/step
# Epoch 739/1000
# 6/6 - 0s - loss: -6.6569e+00 - 33ms/epoch - 5ms/step
# Epoch 740/1000
# 6/6 - 0s - loss: -6.6509e+00 - 33ms/epoch - 5ms/step
# Epoch 741/1000
# 6/6 - 0s - loss: -6.6565e+00 - 35ms/epoch - 6ms/step
# Epoch 742/1000
# 6/6 - 0s - loss: -6.6461e+00 - 38ms/epoch - 6ms/step
# Epoch 743/1000
# 6/6 - 0s - loss: -6.6415e+00 - 34ms/epoch - 6ms/step
# Epoch 744/1000
# 6/6 - 0s - loss: -6.6416e+00 - 32ms/epoch - 5ms/step
# Epoch 745/1000
# 6/6 - 0s - loss: -6.6405e+00 - 34ms/epoch - 6ms/step
# Epoch 746/1000
# 6/6 - 0s - loss: -6.6547e+00 - 40ms/epoch - 7ms/step
# Epoch 747/1000
# 6/6 - 0s - loss: -6.6458e+00 - 31ms/epoch - 5ms/step
# Epoch 748/1000
# 6/6 - 0s - loss: -6.6491e+00 - 33ms/epoch - 5ms/step
# Epoch 749/1000
# 6/6 - 0s - loss: -6.6414e+00 - 34ms/epoch - 6ms/step
# Epoch 750/1000
# 6/6 - 0s - loss: -6.6629e+00 - 33ms/epoch - 5ms/step
# Epoch 751/1000
# 6/6 - 0s - loss: -6.6521e+00 - 35ms/epoch - 6ms/step
# Epoch 752/1000
# 6/6 - 0s - loss: -6.6633e+00 - 32ms/epoch - 5ms/step
# Epoch 753/1000
# 6/6 - 0s - loss: -6.6418e+00 - 33ms/epoch - 5ms/step
# Epoch 754/1000
# 6/6 - 0s - loss: -6.6569e+00 - 33ms/epoch - 6ms/step
# Epoch 755/1000
# 6/6 - 0s - loss: -6.6694e+00 - 34ms/epoch - 6ms/step
# Epoch 756/1000
# 6/6 - 0s - loss: -6.6459e+00 - 32ms/epoch - 5ms/step
# Epoch 757/1000
# 6/6 - 0s - loss: -6.6593e+00 - 34ms/epoch - 6ms/step
# Epoch 758/1000
# 6/6 - 0s - loss: -6.6571e+00 - 32ms/epoch - 5ms/step
# Epoch 759/1000
# 6/6 - 0s - loss: -6.6672e+00 - 35ms/epoch - 6ms/step
# Epoch 760/1000
# 6/6 - 0s - loss: -6.6567e+00 - 34ms/epoch - 6ms/step
# Epoch 761/1000
# 6/6 - 0s - loss: -6.6532e+00 - 33ms/epoch - 6ms/step
# Epoch 762/1000
# 6/6 - 0s - loss: -6.6588e+00 - 33ms/epoch - 6ms/step
# Epoch 763/1000
# 6/6 - 0s - loss: -6.6594e+00 - 34ms/epoch - 6ms/step
# Epoch 764/1000
# 6/6 - 0s - loss: -6.6526e+00 - 34ms/epoch - 6ms/step
# Epoch 765/1000
# 6/6 - 0s - loss: -6.6289e+00 - 34ms/epoch - 6ms/step
# Epoch 766/1000
# 6/6 - 0s - loss: -6.6276e+00 - 32ms/epoch - 5ms/step
# Epoch 767/1000
# 6/6 - 0s - loss: -6.6150e+00 - 33ms/epoch - 5ms/step
# Epoch 768/1000
# 6/6 - 0s - loss: -6.6366e+00 - 33ms/epoch - 5ms/step
# Epoch 769/1000
# 6/6 - 0s - loss: -6.6395e+00 - 33ms/epoch - 6ms/step
# Epoch 770/1000
# 6/6 - 0s - loss: -6.5979e+00 - 34ms/epoch - 6ms/step
# Epoch 771/1000
# 6/6 - 0s - loss: -6.6542e+00 - 34ms/epoch - 6ms/step
# Epoch 772/1000
# 6/6 - 0s - loss: -6.6500e+00 - 33ms/epoch - 5ms/step
# Epoch 773/1000
# 6/6 - 0s - loss: -6.6659e+00 - 35ms/epoch - 6ms/step
# Epoch 774/1000
# 6/6 - 0s - loss: -6.6713e+00 - 38ms/epoch - 6ms/step
# Epoch 775/1000
# 6/6 - 0s - loss: -6.6567e+00 - 36ms/epoch - 6ms/step
# Epoch 776/1000
# 6/6 - 0s - loss: -6.6636e+00 - 35ms/epoch - 6ms/step
# Epoch 777/1000
# 6/6 - 0s - loss: -6.6633e+00 - 35ms/epoch - 6ms/step
# Epoch 778/1000
# 6/6 - 0s - loss: -6.6664e+00 - 34ms/epoch - 6ms/step
# Epoch 779/1000
# 6/6 - 0s - loss: -6.6654e+00 - 32ms/epoch - 5ms/step
# Epoch 780/1000
# 6/6 - 0s - loss: -6.6540e+00 - 33ms/epoch - 5ms/step
# Epoch 781/1000
# 6/6 - 0s - loss: -6.6706e+00 - 33ms/epoch - 5ms/step
# Epoch 782/1000
# 6/6 - 0s - loss: -6.6602e+00 - 34ms/epoch - 6ms/step
# Epoch 783/1000
# 6/6 - 0s - loss: -6.6606e+00 - 33ms/epoch - 5ms/step
# Epoch 784/1000
# 6/6 - 0s - loss: -6.6782e+00 - 35ms/epoch - 6ms/step
# Epoch 785/1000
# 6/6 - 0s - loss: -6.6635e+00 - 32ms/epoch - 5ms/step
# Epoch 786/1000
# 6/6 - 0s - loss: -6.6804e+00 - 33ms/epoch - 6ms/step
# Epoch 787/1000
# 6/6 - 0s - loss: -6.6693e+00 - 33ms/epoch - 6ms/step
# Epoch 788/1000
# 6/6 - 0s - loss: -6.6687e+00 - 33ms/epoch - 6ms/step
# Epoch 789/1000
# 6/6 - 0s - loss: -6.6640e+00 - 34ms/epoch - 6ms/step
# Epoch 790/1000
# 6/6 - 0s - loss: -6.6762e+00 - 35ms/epoch - 6ms/step
# Epoch 791/1000
# 6/6 - 0s - loss: -6.6617e+00 - 37ms/epoch - 6ms/step
# Epoch 792/1000
# 6/6 - 0s - loss: -6.6658e+00 - 36ms/epoch - 6ms/step
# Epoch 793/1000
# 6/6 - 0s - loss: -6.6572e+00 - 35ms/epoch - 6ms/step
# Epoch 794/1000
# 6/6 - 0s - loss: -6.6633e+00 - 34ms/epoch - 6ms/step
# Epoch 795/1000
# 6/6 - 0s - loss: -6.6610e+00 - 36ms/epoch - 6ms/step
# Epoch 796/1000
# 6/6 - 0s - loss: -6.6533e+00 - 36ms/epoch - 6ms/step
# Epoch 797/1000
# 6/6 - 0s - loss: -6.6559e+00 - 39ms/epoch - 6ms/step
# Epoch 798/1000
# 6/6 - 0s - loss: -6.6527e+00 - 38ms/epoch - 6ms/step
# Epoch 799/1000
# 6/6 - 0s - loss: -6.6682e+00 - 33ms/epoch - 5ms/step
# Epoch 800/1000
# 6/6 - 0s - loss: -6.6689e+00 - 33ms/epoch - 6ms/step
# Epoch 801/1000
# 6/6 - 0s - loss: -6.6570e+00 - 37ms/epoch - 6ms/step
# Epoch 802/1000
# 6/6 - 0s - loss: -6.6766e+00 - 36ms/epoch - 6ms/step
# Epoch 803/1000
# 6/6 - 0s - loss: -6.6623e+00 - 35ms/epoch - 6ms/step
# Epoch 804/1000
# 6/6 - 0s - loss: -6.6683e+00 - 37ms/epoch - 6ms/step
# Epoch 805/1000
# 6/6 - 0s - loss: -6.6666e+00 - 34ms/epoch - 6ms/step
# Epoch 806/1000
# 6/6 - 0s - loss: -6.6657e+00 - 32ms/epoch - 5ms/step
# Epoch 807/1000
# 6/6 - 0s - loss: -6.6705e+00 - 33ms/epoch - 6ms/step
# Epoch 808/1000
# 6/6 - 0s - loss: -6.6706e+00 - 35ms/epoch - 6ms/step
# Epoch 809/1000
# 6/6 - 0s - loss: -6.6836e+00 - 31ms/epoch - 5ms/step
# Epoch 810/1000
# 6/6 - 0s - loss: -6.6758e+00 - 36ms/epoch - 6ms/step
# Epoch 811/1000
# 6/6 - 0s - loss: -6.6758e+00 - 34ms/epoch - 6ms/step
# Epoch 812/1000
# 6/6 - 0s - loss: -6.6759e+00 - 31ms/epoch - 5ms/step
# Epoch 813/1000
# 6/6 - 0s - loss: -6.6815e+00 - 36ms/epoch - 6ms/step
# Epoch 814/1000
# 6/6 - 0s - loss: -6.6759e+00 - 36ms/epoch - 6ms/step
# Epoch 815/1000
# 6/6 - 0s - loss: -6.6572e+00 - 36ms/epoch - 6ms/step
# Epoch 816/1000
# 6/6 - 0s - loss: -6.6688e+00 - 34ms/epoch - 6ms/step
# Epoch 817/1000
# 6/6 - 0s - loss: -6.6689e+00 - 39ms/epoch - 6ms/step
# Epoch 818/1000
# 6/6 - 0s - loss: -6.6684e+00 - 38ms/epoch - 6ms/step
# Epoch 819/1000
# 6/6 - 0s - loss: -6.6739e+00 - 38ms/epoch - 6ms/step
# Epoch 820/1000
# 6/6 - 0s - loss: -6.6749e+00 - 37ms/epoch - 6ms/step
# Epoch 821/1000
# 6/6 - 0s - loss: -6.6797e+00 - 38ms/epoch - 6ms/step
# Epoch 822/1000
# 6/6 - 0s - loss: -6.6809e+00 - 31ms/epoch - 5ms/step
# Epoch 823/1000
# 6/6 - 0s - loss: -6.6672e+00 - 34ms/epoch - 6ms/step
# Epoch 824/1000
# 6/6 - 0s - loss: -6.6798e+00 - 32ms/epoch - 5ms/step
# Epoch 825/1000
# 6/6 - 0s - loss: -6.6821e+00 - 31ms/epoch - 5ms/step
# Epoch 826/1000
# 6/6 - 0s - loss: -6.6692e+00 - 32ms/epoch - 5ms/step
# Epoch 827/1000
# 6/6 - 0s - loss: -6.6671e+00 - 35ms/epoch - 6ms/step
# Epoch 828/1000
# 6/6 - 0s - loss: -6.6660e+00 - 33ms/epoch - 6ms/step
# Epoch 829/1000
# 6/6 - 0s - loss: -6.6889e+00 - 32ms/epoch - 5ms/step
# Epoch 830/1000
# 6/6 - 0s - loss: -6.6810e+00 - 35ms/epoch - 6ms/step
# Epoch 831/1000
# 6/6 - 0s - loss: -6.6840e+00 - 32ms/epoch - 5ms/step
# Epoch 832/1000
# 6/6 - 0s - loss: -6.6696e+00 - 34ms/epoch - 6ms/step
# Epoch 833/1000
# 6/6 - 0s - loss: -6.6868e+00 - 33ms/epoch - 5ms/step
# Epoch 834/1000
# 6/6 - 0s - loss: -6.6764e+00 - 32ms/epoch - 5ms/step
# Epoch 835/1000
# 6/6 - 0s - loss: -6.6812e+00 - 32ms/epoch - 5ms/step
# Epoch 836/1000
# 6/6 - 0s - loss: -6.6759e+00 - 32ms/epoch - 5ms/step
# Epoch 837/1000
# 6/6 - 0s - loss: -6.6765e+00 - 37ms/epoch - 6ms/step
# Epoch 838/1000
# 6/6 - 0s - loss: -6.6863e+00 - 37ms/epoch - 6ms/step
# Epoch 839/1000
# 6/6 - 0s - loss: -6.6649e+00 - 31ms/epoch - 5ms/step
# Epoch 840/1000
# 6/6 - 0s - loss: -6.6819e+00 - 32ms/epoch - 5ms/step
# Epoch 841/1000
# 6/6 - 0s - loss: -6.6716e+00 - 33ms/epoch - 6ms/step
# Epoch 842/1000
# 6/6 - 0s - loss: -6.6890e+00 - 34ms/epoch - 6ms/step
# Epoch 843/1000
# 6/6 - 0s - loss: -6.6869e+00 - 35ms/epoch - 6ms/step
# Epoch 844/1000
# 6/6 - 0s - loss: -6.6594e+00 - 35ms/epoch - 6ms/step
# Epoch 845/1000
# 6/6 - 0s - loss: -6.6703e+00 - 32ms/epoch - 5ms/step
# Epoch 846/1000
# 6/6 - 0s - loss: -6.6675e+00 - 33ms/epoch - 5ms/step
# Epoch 847/1000
# 6/6 - 0s - loss: -6.6853e+00 - 31ms/epoch - 5ms/step
# Epoch 848/1000
# 6/6 - 0s - loss: -6.6757e+00 - 31ms/epoch - 5ms/step
# Epoch 849/1000
# 6/6 - 0s - loss: -6.6808e+00 - 36ms/epoch - 6ms/step
# Epoch 850/1000
# 6/6 - 0s - loss: -6.6880e+00 - 33ms/epoch - 6ms/step
# Epoch 851/1000
# 6/6 - 0s - loss: -6.6817e+00 - 39ms/epoch - 7ms/step
# Epoch 852/1000
# 6/6 - 0s - loss: -6.6841e+00 - 31ms/epoch - 5ms/step
# Epoch 853/1000
# 6/6 - 0s - loss: -6.6832e+00 - 35ms/epoch - 6ms/step
# Epoch 854/1000
# 6/6 - 0s - loss: -6.6750e+00 - 32ms/epoch - 5ms/step
# Epoch 855/1000
# 6/6 - 0s - loss: -6.6566e+00 - 34ms/epoch - 6ms/step
# Epoch 856/1000
# 6/6 - 0s - loss: -6.6601e+00 - 32ms/epoch - 5ms/step
# Epoch 857/1000
# 6/6 - 0s - loss: -6.6693e+00 - 34ms/epoch - 6ms/step
# Epoch 858/1000
# 6/6 - 0s - loss: -6.6762e+00 - 34ms/epoch - 6ms/step
# Epoch 859/1000
# 6/6 - 0s - loss: -6.6687e+00 - 34ms/epoch - 6ms/step
# Epoch 860/1000
# 6/6 - 0s - loss: -6.6814e+00 - 36ms/epoch - 6ms/step
# Epoch 861/1000
# 6/6 - 0s - loss: -6.6625e+00 - 34ms/epoch - 6ms/step
# Epoch 862/1000
# 6/6 - 0s - loss: -6.6785e+00 - 32ms/epoch - 5ms/step
# Epoch 863/1000
# 6/6 - 0s - loss: -6.6821e+00 - 32ms/epoch - 5ms/step
# Epoch 864/1000
# 6/6 - 0s - loss: -6.6922e+00 - 34ms/epoch - 6ms/step
# Epoch 865/1000
# 6/6 - 0s - loss: -6.6743e+00 - 36ms/epoch - 6ms/step
# Epoch 866/1000
# 6/6 - 0s - loss: -6.6796e+00 - 34ms/epoch - 6ms/step
# Epoch 867/1000
# 6/6 - 0s - loss: -6.6903e+00 - 31ms/epoch - 5ms/step
# Epoch 868/1000
# 6/6 - 0s - loss: -6.6808e+00 - 33ms/epoch - 5ms/step
# Epoch 869/1000
# 6/6 - 0s - loss: -6.6823e+00 - 33ms/epoch - 6ms/step
# Epoch 870/1000
# 6/6 - 0s - loss: -6.6885e+00 - 33ms/epoch - 6ms/step
# Epoch 871/1000
# 6/6 - 0s - loss: -6.6950e+00 - 32ms/epoch - 5ms/step
# Epoch 872/1000
# 6/6 - 0s - loss: -6.6830e+00 - 33ms/epoch - 6ms/step
# Epoch 873/1000
# 6/6 - 0s - loss: -6.6985e+00 - 33ms/epoch - 6ms/step
# Epoch 874/1000
# 6/6 - 0s - loss: -6.6884e+00 - 33ms/epoch - 6ms/step
# Epoch 875/1000
# 6/6 - 0s - loss: -6.6937e+00 - 32ms/epoch - 5ms/step
# Epoch 876/1000
# 6/6 - 0s - loss: -6.6963e+00 - 32ms/epoch - 5ms/step
# Epoch 877/1000
# 6/6 - 0s - loss: -6.6851e+00 - 34ms/epoch - 6ms/step
# Epoch 878/1000
# 6/6 - 0s - loss: -6.6847e+00 - 33ms/epoch - 6ms/step
# Epoch 879/1000
# 6/6 - 0s - loss: -6.6929e+00 - 34ms/epoch - 6ms/step
# Epoch 880/1000
# 6/6 - 0s - loss: -6.6992e+00 - 32ms/epoch - 5ms/step
# Epoch 881/1000
# 6/6 - 0s - loss: -6.6929e+00 - 32ms/epoch - 5ms/step
# Epoch 882/1000
# 6/6 - 0s - loss: -6.6852e+00 - 34ms/epoch - 6ms/step
# Epoch 883/1000
# 6/6 - 0s - loss: -6.6863e+00 - 33ms/epoch - 6ms/step
# Epoch 884/1000
# 6/6 - 0s - loss: -6.6991e+00 - 33ms/epoch - 5ms/step
# Epoch 885/1000
# 6/6 - 0s - loss: -6.6919e+00 - 30ms/epoch - 5ms/step
# Epoch 886/1000
# 6/6 - 0s - loss: -6.6890e+00 - 32ms/epoch - 5ms/step
# Epoch 887/1000
# 6/6 - 0s - loss: -6.6991e+00 - 33ms/epoch - 6ms/step
# Epoch 888/1000
# 6/6 - 0s - loss: -6.6890e+00 - 34ms/epoch - 6ms/step
# Epoch 889/1000
# 6/6 - 0s - loss: -6.7052e+00 - 33ms/epoch - 5ms/step
# Epoch 890/1000
# 6/6 - 0s - loss: -6.6841e+00 - 31ms/epoch - 5ms/step
# Epoch 891/1000
# 6/6 - 0s - loss: -6.6955e+00 - 34ms/epoch - 6ms/step
# Epoch 892/1000
# 6/6 - 0s - loss: -6.6839e+00 - 36ms/epoch - 6ms/step
# Epoch 893/1000
# 6/6 - 0s - loss: -6.6906e+00 - 34ms/epoch - 6ms/step
# Epoch 894/1000
# 6/6 - 0s - loss: -6.6868e+00 - 36ms/epoch - 6ms/step
# Epoch 895/1000
# 6/6 - 0s - loss: -6.6999e+00 - 34ms/epoch - 6ms/step
# Epoch 896/1000
# 6/6 - 0s - loss: -6.6836e+00 - 34ms/epoch - 6ms/step
# Epoch 897/1000
# 6/6 - 0s - loss: -6.6117e+00 - 33ms/epoch - 6ms/step
# Epoch 898/1000
# 6/6 - 0s - loss: -6.6171e+00 - 35ms/epoch - 6ms/step
# Epoch 899/1000
# 6/6 - 0s - loss: -6.6652e+00 - 33ms/epoch - 5ms/step
# Epoch 900/1000
# 6/6 - 0s - loss: -6.6861e+00 - 32ms/epoch - 5ms/step
# Epoch 901/1000
# 6/6 - 0s - loss: -6.6749e+00 - 33ms/epoch - 6ms/step
# Epoch 902/1000
# 6/6 - 0s - loss: -6.6753e+00 - 34ms/epoch - 6ms/step
# Epoch 903/1000
# 6/6 - 0s - loss: -6.6858e+00 - 32ms/epoch - 5ms/step
# Epoch 904/1000
# 6/6 - 0s - loss: -6.6924e+00 - 32ms/epoch - 5ms/step
# Epoch 905/1000
# 6/6 - 0s - loss: -6.6865e+00 - 33ms/epoch - 5ms/step
# Epoch 906/1000
# 6/6 - 0s - loss: -6.7026e+00 - 35ms/epoch - 6ms/step
# Epoch 907/1000
# 6/6 - 0s - loss: -6.6841e+00 - 33ms/epoch - 5ms/step
# Epoch 908/1000
# 6/6 - 0s - loss: -6.6835e+00 - 31ms/epoch - 5ms/step
# Epoch 909/1000
# 6/6 - 0s - loss: -6.6851e+00 - 34ms/epoch - 6ms/step
# Epoch 910/1000
# 6/6 - 0s - loss: -6.6883e+00 - 31ms/epoch - 5ms/step
# Epoch 911/1000
# 6/6 - 0s - loss: -6.6684e+00 - 35ms/epoch - 6ms/step
# Epoch 912/1000
# 6/6 - 0s - loss: -6.6837e+00 - 33ms/epoch - 5ms/step
# Epoch 913/1000
# 6/6 - 0s - loss: -6.6768e+00 - 33ms/epoch - 5ms/step
# Epoch 914/1000
# 6/6 - 0s - loss: -6.6913e+00 - 32ms/epoch - 5ms/step
# Epoch 915/1000
# 6/6 - 0s - loss: -6.6860e+00 - 35ms/epoch - 6ms/step
# Epoch 916/1000
# 6/6 - 0s - loss: -6.6895e+00 - 31ms/epoch - 5ms/step
# Epoch 917/1000
# 6/6 - 0s - loss: -6.6801e+00 - 35ms/epoch - 6ms/step
# Epoch 918/1000
# 6/6 - 0s - loss: -6.6827e+00 - 33ms/epoch - 5ms/step
# Epoch 919/1000
# 6/6 - 0s - loss: -6.6877e+00 - 31ms/epoch - 5ms/step
# Epoch 920/1000
# 6/6 - 0s - loss: -6.6897e+00 - 32ms/epoch - 5ms/step
# Epoch 921/1000
# 6/6 - 0s - loss: -6.6891e+00 - 34ms/epoch - 6ms/step
# Epoch 922/1000
# 6/6 - 0s - loss: -6.6919e+00 - 32ms/epoch - 5ms/step
# Epoch 923/1000
# 6/6 - 0s - loss: -6.6970e+00 - 35ms/epoch - 6ms/step
# Epoch 924/1000
# 6/6 - 0s - loss: -6.6954e+00 - 32ms/epoch - 5ms/step
# Epoch 925/1000
# 6/6 - 0s - loss: -6.6928e+00 - 33ms/epoch - 5ms/step
# Epoch 926/1000
# 6/6 - 0s - loss: -6.6948e+00 - 32ms/epoch - 5ms/step
# Epoch 927/1000
# 6/6 - 0s - loss: -6.7054e+00 - 32ms/epoch - 5ms/step
# Epoch 928/1000
# 6/6 - 0s - loss: -6.6881e+00 - 34ms/epoch - 6ms/step
# Epoch 929/1000
# 6/6 - 0s - loss: -6.6848e+00 - 35ms/epoch - 6ms/step
# Epoch 930/1000
# 6/6 - 0s - loss: -6.6757e+00 - 33ms/epoch - 6ms/step
# Epoch 931/1000
# 6/6 - 0s - loss: -6.6935e+00 - 32ms/epoch - 5ms/step
# Epoch 932/1000
# 6/6 - 0s - loss: -6.6995e+00 - 32ms/epoch - 5ms/step
# Epoch 933/1000
# 6/6 - 0s - loss: -6.6999e+00 - 32ms/epoch - 5ms/step
# Epoch 934/1000
# 6/6 - 0s - loss: -6.7028e+00 - 31ms/epoch - 5ms/step
# Epoch 935/1000
# 6/6 - 0s - loss: -6.6917e+00 - 34ms/epoch - 6ms/step
# Epoch 936/1000
# 6/6 - 0s - loss: -6.6987e+00 - 32ms/epoch - 5ms/step
# Epoch 937/1000
# 6/6 - 0s - loss: -6.6902e+00 - 42ms/epoch - 7ms/step
# Epoch 938/1000
# 6/6 - 0s - loss: -6.6897e+00 - 31ms/epoch - 5ms/step
# Epoch 939/1000
# 6/6 - 0s - loss: -6.7010e+00 - 32ms/epoch - 5ms/step
# Epoch 940/1000
# 6/6 - 0s - loss: -6.6938e+00 - 32ms/epoch - 5ms/step
# Epoch 941/1000
# 6/6 - 0s - loss: -6.6922e+00 - 33ms/epoch - 5ms/step
# Epoch 942/1000
# 6/6 - 0s - loss: -6.7070e+00 - 32ms/epoch - 5ms/step
# Epoch 943/1000
# 6/6 - 0s - loss: -6.6885e+00 - 31ms/epoch - 5ms/step
# Epoch 944/1000
# 6/6 - 0s - loss: -6.6987e+00 - 31ms/epoch - 5ms/step
# Epoch 945/1000
# 6/6 - 0s - loss: -6.6898e+00 - 40ms/epoch - 7ms/step
# Epoch 946/1000
# 6/6 - 0s - loss: -6.6773e+00 - 36ms/epoch - 6ms/step
# Epoch 947/1000
# 6/6 - 0s - loss: -6.6704e+00 - 33ms/epoch - 5ms/step
# Epoch 948/1000
# 6/6 - 0s - loss: -6.6844e+00 - 31ms/epoch - 5ms/step
# Epoch 949/1000
# 6/6 - 0s - loss: -6.6843e+00 - 34ms/epoch - 6ms/step
# Epoch 950/1000
# 6/6 - 0s - loss: -6.6856e+00 - 36ms/epoch - 6ms/step
# Epoch 951/1000
# 6/6 - 0s - loss: -6.6851e+00 - 35ms/epoch - 6ms/step
# Epoch 952/1000
# 6/6 - 0s - loss: -6.6730e+00 - 32ms/epoch - 5ms/step
# Epoch 953/1000
# 6/6 - 0s - loss: -6.6844e+00 - 33ms/epoch - 5ms/step
# Epoch 954/1000
# 6/6 - 0s - loss: -6.6811e+00 - 36ms/epoch - 6ms/step
# Epoch 955/1000
# 6/6 - 0s - loss: -6.6944e+00 - 35ms/epoch - 6ms/step
# Epoch 956/1000
# 6/6 - 0s - loss: -6.6876e+00 - 32ms/epoch - 5ms/step
# Epoch 957/1000
# 6/6 - 0s - loss: -6.6924e+00 - 34ms/epoch - 6ms/step
# Epoch 958/1000
# 6/6 - 0s - loss: -6.7024e+00 - 31ms/epoch - 5ms/step
# Epoch 959/1000
# 6/6 - 0s - loss: -6.6984e+00 - 33ms/epoch - 6ms/step
# Epoch 960/1000
# 6/6 - 0s - loss: -6.6938e+00 - 31ms/epoch - 5ms/step
# Epoch 961/1000
# 6/6 - 0s - loss: -6.7041e+00 - 32ms/epoch - 5ms/step
# Epoch 962/1000
# 6/6 - 0s - loss: -6.6996e+00 - 33ms/epoch - 6ms/step
# Epoch 963/1000
# 6/6 - 0s - loss: -6.7007e+00 - 35ms/epoch - 6ms/step
# Epoch 964/1000
# 6/6 - 0s - loss: -6.7053e+00 - 33ms/epoch - 6ms/step
# Epoch 965/1000
# 6/6 - 0s - loss: -6.6903e+00 - 34ms/epoch - 6ms/step
# Epoch 966/1000
# 6/6 - 0s - loss: -6.6951e+00 - 32ms/epoch - 5ms/step
# Epoch 967/1000
# 6/6 - 0s - loss: -6.6934e+00 - 35ms/epoch - 6ms/step
# Epoch 968/1000
# 6/6 - 0s - loss: -6.6973e+00 - 32ms/epoch - 5ms/step
# Epoch 969/1000
# 6/6 - 0s - loss: -6.6966e+00 - 33ms/epoch - 6ms/step
# Epoch 970/1000
# 6/6 - 0s - loss: -6.6969e+00 - 34ms/epoch - 6ms/step
# Epoch 971/1000
# 6/6 - 0s - loss: -6.6980e+00 - 33ms/epoch - 6ms/step
# Epoch 972/1000
# 6/6 - 0s - loss: -6.7048e+00 - 34ms/epoch - 6ms/step
# Epoch 973/1000
# 6/6 - 0s - loss: -6.6994e+00 - 35ms/epoch - 6ms/step
# Epoch 974/1000
# 6/6 - 0s - loss: -6.7069e+00 - 33ms/epoch - 6ms/step
# Epoch 975/1000
# 6/6 - 0s - loss: -6.7083e+00 - 33ms/epoch - 5ms/step
# Epoch 976/1000
# 6/6 - 0s - loss: -6.7023e+00 - 32ms/epoch - 5ms/step
# Epoch 977/1000
# 6/6 - 0s - loss: -6.7112e+00 - 32ms/epoch - 5ms/step
# Epoch 978/1000
# 6/6 - 0s - loss: -6.6969e+00 - 32ms/epoch - 5ms/step
# Epoch 979/1000
# 6/6 - 0s - loss: -6.7130e+00 - 35ms/epoch - 6ms/step
# Epoch 980/1000
# 6/6 - 0s - loss: -6.7085e+00 - 31ms/epoch - 5ms/step
# Epoch 981/1000
# 6/6 - 0s - loss: -6.7009e+00 - 36ms/epoch - 6ms/step
# Epoch 982/1000
# 6/6 - 0s - loss: -6.7022e+00 - 34ms/epoch - 6ms/step
# Epoch 983/1000
# 6/6 - 0s - loss: -6.7062e+00 - 33ms/epoch - 6ms/step
# Epoch 984/1000
# 6/6 - 0s - loss: -6.7000e+00 - 32ms/epoch - 5ms/step
# Epoch 985/1000
# 6/6 - 0s - loss: -6.7005e+00 - 33ms/epoch - 5ms/step
# Epoch 986/1000
# 6/6 - 0s - loss: -6.6847e+00 - 31ms/epoch - 5ms/step
# Epoch 987/1000
# 6/6 - 0s - loss: -6.6837e+00 - 35ms/epoch - 6ms/step
# Epoch 988/1000
# 6/6 - 0s - loss: -6.6972e+00 - 32ms/epoch - 5ms/step
# Epoch 989/1000
# 6/6 - 0s - loss: -6.6890e+00 - 32ms/epoch - 5ms/step
# Epoch 990/1000
# 6/6 - 0s - loss: -6.6980e+00 - 31ms/epoch - 5ms/step
# Epoch 991/1000
# 6/6 - 0s - loss: -6.7014e+00 - 34ms/epoch - 6ms/step
# Epoch 992/1000
# 6/6 - 0s - loss: -6.6930e+00 - 35ms/epoch - 6ms/step
# Epoch 993/1000
# 6/6 - 0s - loss: -6.7019e+00 - 33ms/epoch - 6ms/step
# Epoch 994/1000
# 6/6 - 0s - loss: -6.7075e+00 - 33ms/epoch - 6ms/step
# Epoch 995/1000
# 6/6 - 0s - loss: -6.7143e+00 - 33ms/epoch - 6ms/step
# Epoch 996/1000
# 6/6 - 0s - loss: -6.7143e+00 - 35ms/epoch - 6ms/step
# Epoch 997/1000
# 6/6 - 0s - loss: -6.7136e+00 - 32ms/epoch - 5ms/step
# Epoch 998/1000
# 6/6 - 0s - loss: -6.6985e+00 - 34ms/epoch - 6ms/step
# Epoch 999/1000
# 6/6 - 0s - loss: -6.7071e+00 - 33ms/epoch - 5ms/step
# Epoch 1000/1000
# 6/6 - 0s - loss: -6.7134e+00 - 36ms/epoch - 6ms/step
# Epoch 1/1000
# 6/6 - 1s - loss: -8.0556e-01 - 1s/epoch - 191ms/step
# Epoch 2/1000
# 6/6 - 0s - loss: -1.4370e+00 - 33ms/epoch - 5ms/step
# Epoch 3/1000
# 6/6 - 0s - loss: -1.8244e+00 - 32ms/epoch - 5ms/step
# Epoch 4/1000
# 6/6 - 0s - loss: -2.2099e+00 - 32ms/epoch - 5ms/step
# Epoch 5/1000
# 6/6 - 0s - loss: -2.4529e+00 - 33ms/epoch - 6ms/step
# Epoch 6/1000
# 6/6 - 0s - loss: -2.6593e+00 - 34ms/epoch - 6ms/step
# Epoch 7/1000
# 6/6 - 0s - loss: -2.8388e+00 - 34ms/epoch - 6ms/step
# Epoch 8/1000
# 6/6 - 0s - loss: -2.9652e+00 - 31ms/epoch - 5ms/step
# Epoch 9/1000
# 6/6 - 0s - loss: -3.0983e+00 - 34ms/epoch - 6ms/step
# Epoch 10/1000
# 6/6 - 0s - loss: -3.3373e+00 - 36ms/epoch - 6ms/step
# Epoch 11/1000
# 6/6 - 0s - loss: -3.6956e+00 - 34ms/epoch - 6ms/step
# Epoch 12/1000
# 6/6 - 0s - loss: -3.9660e+00 - 35ms/epoch - 6ms/step
# Epoch 13/1000
# 6/6 - 0s - loss: -4.2153e+00 - 35ms/epoch - 6ms/step
# Epoch 14/1000
# 6/6 - 0s - loss: -4.5168e+00 - 34ms/epoch - 6ms/step
# Epoch 15/1000
# 6/6 - 0s - loss: -4.7843e+00 - 34ms/epoch - 6ms/step
# Epoch 16/1000
# 6/6 - 0s - loss: -4.8919e+00 - 31ms/epoch - 5ms/step
# Epoch 17/1000
# 6/6 - 0s - loss: -5.0272e+00 - 34ms/epoch - 6ms/step
# Epoch 18/1000
# 6/6 - 0s - loss: -5.0865e+00 - 33ms/epoch - 5ms/step
# Epoch 19/1000
# 6/6 - 0s - loss: -5.1104e+00 - 33ms/epoch - 5ms/step
# Epoch 20/1000
# 6/6 - 0s - loss: -5.1398e+00 - 36ms/epoch - 6ms/step
# Epoch 21/1000
# 6/6 - 0s - loss: -5.1404e+00 - 33ms/epoch - 6ms/step
# Epoch 22/1000
# 6/6 - 0s - loss: -5.1826e+00 - 31ms/epoch - 5ms/step
# Epoch 23/1000
# 6/6 - 0s - loss: -5.1827e+00 - 30ms/epoch - 5ms/step
# Epoch 24/1000
# 6/6 - 0s - loss: -5.1871e+00 - 33ms/epoch - 6ms/step
# Epoch 25/1000
# 6/6 - 0s - loss: -5.1716e+00 - 34ms/epoch - 6ms/step
# Epoch 26/1000
# 6/6 - 0s - loss: -5.2076e+00 - 34ms/epoch - 6ms/step
# Epoch 27/1000
# 6/6 - 0s - loss: -5.2324e+00 - 33ms/epoch - 6ms/step
# Epoch 28/1000
# 6/6 - 0s - loss: -5.2309e+00 - 32ms/epoch - 5ms/step
# Epoch 29/1000
# 6/6 - 0s - loss: -5.2022e+00 - 34ms/epoch - 6ms/step
# Epoch 30/1000
# 6/6 - 0s - loss: -5.2325e+00 - 34ms/epoch - 6ms/step
# Epoch 31/1000
# 6/6 - 0s - loss: -5.2214e+00 - 35ms/epoch - 6ms/step
# Epoch 32/1000
# 6/6 - 0s - loss: -5.2311e+00 - 33ms/epoch - 5ms/step
# Epoch 33/1000
# 6/6 - 0s - loss: -5.2531e+00 - 33ms/epoch - 5ms/step
# Epoch 34/1000
# 6/6 - 0s - loss: -5.2101e+00 - 33ms/epoch - 5ms/step
# Epoch 35/1000
# 6/6 - 0s - loss: -5.2504e+00 - 33ms/epoch - 6ms/step
# Epoch 36/1000
# 6/6 - 0s - loss: -5.2141e+00 - 32ms/epoch - 5ms/step
# Epoch 37/1000
# 6/6 - 0s - loss: -5.1940e+00 - 33ms/epoch - 5ms/step
# Epoch 38/1000
# 6/6 - 0s - loss: -5.1993e+00 - 33ms/epoch - 5ms/step
# Epoch 39/1000
# 6/6 - 0s - loss: -5.2881e+00 - 34ms/epoch - 6ms/step
# Epoch 40/1000
# 6/6 - 0s - loss: -5.3239e+00 - 33ms/epoch - 6ms/step
# Epoch 41/1000
# 6/6 - 0s - loss: -5.3357e+00 - 33ms/epoch - 6ms/step
# Epoch 42/1000
# 6/6 - 0s - loss: -5.3184e+00 - 33ms/epoch - 6ms/step
# Epoch 43/1000
# 6/6 - 0s - loss: -5.3357e+00 - 34ms/epoch - 6ms/step
# Epoch 44/1000
# 6/6 - 0s - loss: -5.3463e+00 - 32ms/epoch - 5ms/step
# Epoch 45/1000
# 6/6 - 0s - loss: -5.3129e+00 - 33ms/epoch - 6ms/step
# Epoch 46/1000
# 6/6 - 0s - loss: -5.3708e+00 - 34ms/epoch - 6ms/step
# Epoch 47/1000
# 6/6 - 0s - loss: -5.3475e+00 - 36ms/epoch - 6ms/step
# Epoch 48/1000
# 6/6 - 0s - loss: -5.3534e+00 - 32ms/epoch - 5ms/step
# Epoch 49/1000
# 6/6 - 0s - loss: -5.3155e+00 - 32ms/epoch - 5ms/step
# Epoch 50/1000
# 6/6 - 0s - loss: -5.3300e+00 - 35ms/epoch - 6ms/step
# Epoch 51/1000
# 6/6 - 0s - loss: -5.3324e+00 - 33ms/epoch - 5ms/step
# Epoch 52/1000
# 6/6 - 0s - loss: -5.3475e+00 - 33ms/epoch - 5ms/step
# Epoch 53/1000
# 6/6 - 0s - loss: -5.3221e+00 - 31ms/epoch - 5ms/step
# Epoch 54/1000
# 6/6 - 0s - loss: -5.3429e+00 - 34ms/epoch - 6ms/step
# Epoch 55/1000
# 6/6 - 0s - loss: -5.3928e+00 - 37ms/epoch - 6ms/step
# Epoch 56/1000
# 6/6 - 0s - loss: -5.3703e+00 - 32ms/epoch - 5ms/step
# Epoch 57/1000
# 6/6 - 0s - loss: -5.3904e+00 - 33ms/epoch - 6ms/step
# Epoch 58/1000
# 6/6 - 0s - loss: -5.3594e+00 - 31ms/epoch - 5ms/step
# Epoch 59/1000
# 6/6 - 0s - loss: -5.3887e+00 - 35ms/epoch - 6ms/step
# Epoch 60/1000
# 6/6 - 0s - loss: -5.3421e+00 - 34ms/epoch - 6ms/step
# Epoch 61/1000
# 6/6 - 0s - loss: -5.3608e+00 - 33ms/epoch - 6ms/step
# Epoch 62/1000
# 6/6 - 0s - loss: -5.3836e+00 - 33ms/epoch - 6ms/step
# Epoch 63/1000
# 6/6 - 0s - loss: -5.4252e+00 - 35ms/epoch - 6ms/step
# Epoch 64/1000
# 6/6 - 0s - loss: -5.3718e+00 - 34ms/epoch - 6ms/step
# Epoch 65/1000
# 6/6 - 0s - loss: -5.3768e+00 - 34ms/epoch - 6ms/step
# Epoch 66/1000
# 6/6 - 0s - loss: -5.4119e+00 - 32ms/epoch - 5ms/step
# Epoch 67/1000
# 6/6 - 0s - loss: -5.4274e+00 - 32ms/epoch - 5ms/step
# Epoch 68/1000
# 6/6 - 0s - loss: -5.4050e+00 - 33ms/epoch - 6ms/step
# Epoch 69/1000
# 6/6 - 0s - loss: -5.4097e+00 - 34ms/epoch - 6ms/step
# Epoch 70/1000
# 6/6 - 0s - loss: -5.3630e+00 - 34ms/epoch - 6ms/step
# Epoch 71/1000
# 6/6 - 0s - loss: -5.3572e+00 - 39ms/epoch - 7ms/step
# Epoch 72/1000
# 6/6 - 0s - loss: -5.4256e+00 - 31ms/epoch - 5ms/step
# Epoch 73/1000
# 6/6 - 0s - loss: -5.4089e+00 - 34ms/epoch - 6ms/step
# Epoch 74/1000
# 6/6 - 0s - loss: -5.4055e+00 - 34ms/epoch - 6ms/step
# Epoch 75/1000
# 6/6 - 0s - loss: -5.4042e+00 - 33ms/epoch - 5ms/step
# Epoch 76/1000
# 6/6 - 0s - loss: -5.3385e+00 - 32ms/epoch - 5ms/step
# Epoch 77/1000
# 6/6 - 0s - loss: -5.3306e+00 - 38ms/epoch - 6ms/step
# Epoch 78/1000
# 6/6 - 0s - loss: -5.3319e+00 - 35ms/epoch - 6ms/step
# Epoch 79/1000
# 6/6 - 0s - loss: -5.3069e+00 - 33ms/epoch - 5ms/step
# Epoch 80/1000
# 6/6 - 0s - loss: -5.3515e+00 - 32ms/epoch - 5ms/step
# Epoch 81/1000
# 6/6 - 0s - loss: -5.3519e+00 - 32ms/epoch - 5ms/step
# Epoch 82/1000
# 6/6 - 0s - loss: -5.3507e+00 - 32ms/epoch - 5ms/step
# Epoch 83/1000
# 6/6 - 0s - loss: -5.2727e+00 - 34ms/epoch - 6ms/step
# Epoch 84/1000
# 6/6 - 0s - loss: -5.2492e+00 - 34ms/epoch - 6ms/step
# Epoch 85/1000
# 6/6 - 0s - loss: -5.2459e+00 - 34ms/epoch - 6ms/step
# Epoch 86/1000
# 6/6 - 0s - loss: -5.2605e+00 - 34ms/epoch - 6ms/step
# Epoch 87/1000
# 6/6 - 0s - loss: -5.2928e+00 - 31ms/epoch - 5ms/step
# Epoch 88/1000
# 6/6 - 0s - loss: -5.3022e+00 - 35ms/epoch - 6ms/step
# Epoch 89/1000
# 6/6 - 0s - loss: -5.3362e+00 - 31ms/epoch - 5ms/step
# Epoch 90/1000
# 6/6 - 0s - loss: -5.3893e+00 - 33ms/epoch - 5ms/step
# Epoch 91/1000
# 6/6 - 0s - loss: -5.3629e+00 - 33ms/epoch - 5ms/step
# Epoch 92/1000
# 6/6 - 0s - loss: -5.3713e+00 - 35ms/epoch - 6ms/step
# Epoch 93/1000
# 6/6 - 0s - loss: -5.3713e+00 - 33ms/epoch - 6ms/step
# Epoch 94/1000
# 6/6 - 0s - loss: -5.4046e+00 - 34ms/epoch - 6ms/step
# Epoch 95/1000
# 6/6 - 0s - loss: -5.4158e+00 - 33ms/epoch - 5ms/step
# Epoch 96/1000
# 6/6 - 0s - loss: -5.4112e+00 - 36ms/epoch - 6ms/step
# Epoch 97/1000
# 6/6 - 0s - loss: -5.4033e+00 - 33ms/epoch - 6ms/step
# Epoch 98/1000
# 6/6 - 0s - loss: -5.3799e+00 - 32ms/epoch - 5ms/step
# Epoch 99/1000
# 6/6 - 0s - loss: -5.3943e+00 - 32ms/epoch - 5ms/step
# Epoch 100/1000
# 6/6 - 0s - loss: -5.4195e+00 - 34ms/epoch - 6ms/step
# Epoch 101/1000
# 6/6 - 0s - loss: -5.3963e+00 - 34ms/epoch - 6ms/step
# Epoch 102/1000
# 6/6 - 0s - loss: -5.4079e+00 - 33ms/epoch - 5ms/step
# Epoch 103/1000
# 6/6 - 0s - loss: -5.4240e+00 - 30ms/epoch - 5ms/step
# Epoch 104/1000
# 6/6 - 0s - loss: -5.4584e+00 - 35ms/epoch - 6ms/step
# Epoch 105/1000
# 6/6 - 0s - loss: -5.4358e+00 - 38ms/epoch - 6ms/step
# Epoch 106/1000
# 6/6 - 0s - loss: -5.4622e+00 - 34ms/epoch - 6ms/step
# Epoch 107/1000
# 6/6 - 0s - loss: -5.4527e+00 - 33ms/epoch - 6ms/step
# Epoch 108/1000
# 6/6 - 0s - loss: -5.4330e+00 - 33ms/epoch - 5ms/step
# Epoch 109/1000
# 6/6 - 0s - loss: -5.4839e+00 - 31ms/epoch - 5ms/step
# Epoch 110/1000
# 6/6 - 0s - loss: -5.4901e+00 - 36ms/epoch - 6ms/step
# Epoch 111/1000
# 6/6 - 0s - loss: -5.4584e+00 - 34ms/epoch - 6ms/step
# Epoch 112/1000
# 6/6 - 0s - loss: -5.4747e+00 - 33ms/epoch - 5ms/step
# Epoch 113/1000
# 6/6 - 0s - loss: -5.4837e+00 - 32ms/epoch - 5ms/step
# Epoch 114/1000
# 6/6 - 0s - loss: -5.4778e+00 - 33ms/epoch - 5ms/step
# Epoch 115/1000
# 6/6 - 0s - loss: -5.4963e+00 - 33ms/epoch - 6ms/step
# Epoch 116/1000
# 6/6 - 0s - loss: -5.4890e+00 - 33ms/epoch - 5ms/step
# Epoch 117/1000
# 6/6 - 0s - loss: -5.4992e+00 - 32ms/epoch - 5ms/step
# Epoch 118/1000
# 6/6 - 0s - loss: -5.4574e+00 - 33ms/epoch - 6ms/step
# Epoch 119/1000
# 6/6 - 0s - loss: -5.4907e+00 - 32ms/epoch - 5ms/step
# Epoch 120/1000
# 6/6 - 0s - loss: -5.4685e+00 - 32ms/epoch - 5ms/step
# Epoch 121/1000
# 6/6 - 0s - loss: -5.4750e+00 - 37ms/epoch - 6ms/step
# Epoch 122/1000
# 6/6 - 0s - loss: -5.4368e+00 - 33ms/epoch - 5ms/step
# Epoch 123/1000
# 6/6 - 0s - loss: -5.4524e+00 - 31ms/epoch - 5ms/step
# Epoch 124/1000
# 6/6 - 0s - loss: -5.4428e+00 - 34ms/epoch - 6ms/step
# Epoch 125/1000
# 6/6 - 0s - loss: -5.4164e+00 - 42ms/epoch - 7ms/step
# Epoch 126/1000
# 6/6 - 0s - loss: -5.4230e+00 - 33ms/epoch - 6ms/step
# Epoch 127/1000
# 6/6 - 0s - loss: -5.4409e+00 - 32ms/epoch - 5ms/step
# Epoch 128/1000
# 6/6 - 0s - loss: -5.4318e+00 - 32ms/epoch - 5ms/step
# Epoch 129/1000
# 6/6 - 0s - loss: -5.4629e+00 - 33ms/epoch - 5ms/step
# Epoch 130/1000
# 6/6 - 0s - loss: -5.4573e+00 - 33ms/epoch - 5ms/step
# Epoch 131/1000
# 6/6 - 0s - loss: -5.4459e+00 - 34ms/epoch - 6ms/step
# Epoch 132/1000
# 6/6 - 0s - loss: -5.4928e+00 - 32ms/epoch - 5ms/step
# Epoch 133/1000
# 6/6 - 0s - loss: -5.4743e+00 - 33ms/epoch - 6ms/step
# Epoch 134/1000
# 6/6 - 0s - loss: -5.5178e+00 - 33ms/epoch - 6ms/step
# Epoch 135/1000
# 6/6 - 0s - loss: -5.5258e+00 - 34ms/epoch - 6ms/step
# Epoch 136/1000
# 6/6 - 0s - loss: -5.5100e+00 - 34ms/epoch - 6ms/step
# Epoch 137/1000
# 6/6 - 0s - loss: -5.4880e+00 - 31ms/epoch - 5ms/step
# Epoch 138/1000
# 6/6 - 0s - loss: -5.4862e+00 - 35ms/epoch - 6ms/step
# Epoch 139/1000
# 6/6 - 0s - loss: -5.4643e+00 - 33ms/epoch - 5ms/step
# Epoch 140/1000
# 6/6 - 0s - loss: -5.4753e+00 - 34ms/epoch - 6ms/step
# Epoch 141/1000
# 6/6 - 0s - loss: -5.5182e+00 - 33ms/epoch - 5ms/step
# Epoch 142/1000
# 6/6 - 0s - loss: -5.4881e+00 - 32ms/epoch - 5ms/step
# Epoch 143/1000
# 6/6 - 0s - loss: -5.5137e+00 - 37ms/epoch - 6ms/step
# Epoch 144/1000
# 6/6 - 0s - loss: -5.4994e+00 - 35ms/epoch - 6ms/step
# Epoch 145/1000
# 6/6 - 0s - loss: -5.5175e+00 - 32ms/epoch - 5ms/step
# Epoch 146/1000
# 6/6 - 0s - loss: -5.5246e+00 - 33ms/epoch - 5ms/step
# Epoch 147/1000
# 6/6 - 0s - loss: -5.5155e+00 - 34ms/epoch - 6ms/step
# Epoch 148/1000
# 6/6 - 0s - loss: -5.5213e+00 - 33ms/epoch - 5ms/step
# Epoch 149/1000
# 6/6 - 0s - loss: -5.5124e+00 - 35ms/epoch - 6ms/step
# Epoch 150/1000
# 6/6 - 0s - loss: -5.5241e+00 - 33ms/epoch - 6ms/step
# Epoch 151/1000
# 6/6 - 0s - loss: -5.5339e+00 - 35ms/epoch - 6ms/step
# Epoch 152/1000
# 6/6 - 0s - loss: -5.5293e+00 - 33ms/epoch - 5ms/step
# Epoch 153/1000
# 6/6 - 0s - loss: -5.5115e+00 - 32ms/epoch - 5ms/step
# Epoch 154/1000
# 6/6 - 0s - loss: -5.5210e+00 - 34ms/epoch - 6ms/step
# Epoch 155/1000
# 6/6 - 0s - loss: -5.5296e+00 - 39ms/epoch - 7ms/step
# Epoch 156/1000
# 6/6 - 0s - loss: -5.5153e+00 - 33ms/epoch - 5ms/step
# Epoch 157/1000
# 6/6 - 0s - loss: -5.5077e+00 - 32ms/epoch - 5ms/step
# Epoch 158/1000
# 6/6 - 0s - loss: -5.4930e+00 - 32ms/epoch - 5ms/step
# Epoch 159/1000
# 6/6 - 0s - loss: -5.4917e+00 - 35ms/epoch - 6ms/step
# Epoch 160/1000
# 6/6 - 0s - loss: -5.4996e+00 - 33ms/epoch - 5ms/step
# Epoch 161/1000
# 6/6 - 0s - loss: -5.5198e+00 - 36ms/epoch - 6ms/step
# Epoch 162/1000
# 6/6 - 0s - loss: -5.5085e+00 - 34ms/epoch - 6ms/step
# Epoch 163/1000
# 6/6 - 0s - loss: -5.5360e+00 - 33ms/epoch - 5ms/step
# Epoch 164/1000
# 6/6 - 0s - loss: -5.5428e+00 - 34ms/epoch - 6ms/step
# Epoch 165/1000
# 6/6 - 0s - loss: -5.5270e+00 - 37ms/epoch - 6ms/step
# Epoch 166/1000
# 6/6 - 0s - loss: -5.5483e+00 - 33ms/epoch - 6ms/step
# Epoch 167/1000
# 6/6 - 0s - loss: -5.5307e+00 - 34ms/epoch - 6ms/step
# Epoch 168/1000
# 6/6 - 0s - loss: -5.5285e+00 - 35ms/epoch - 6ms/step
# Epoch 169/1000
# 6/6 - 0s - loss: -5.5491e+00 - 34ms/epoch - 6ms/step
# Epoch 170/1000
# 6/6 - 0s - loss: -5.5379e+00 - 31ms/epoch - 5ms/step
# Epoch 171/1000
# 6/6 - 0s - loss: -5.5402e+00 - 33ms/epoch - 6ms/step
# Epoch 172/1000
# 6/6 - 0s - loss: -5.5531e+00 - 35ms/epoch - 6ms/step
# Epoch 173/1000
# 6/6 - 0s - loss: -5.5343e+00 - 33ms/epoch - 6ms/step
# Epoch 174/1000
# 6/6 - 0s - loss: -5.5288e+00 - 32ms/epoch - 5ms/step
# Epoch 175/1000
# 6/6 - 0s - loss: -5.5388e+00 - 32ms/epoch - 5ms/step
# Epoch 176/1000
# 6/6 - 0s - loss: -5.5144e+00 - 32ms/epoch - 5ms/step
# Epoch 177/1000
# 6/6 - 0s - loss: -5.5434e+00 - 35ms/epoch - 6ms/step
# Epoch 178/1000
# 6/6 - 0s - loss: -5.5389e+00 - 31ms/epoch - 5ms/step
# Epoch 179/1000
# 6/6 - 0s - loss: -5.5540e+00 - 33ms/epoch - 5ms/step
# Epoch 180/1000
# 6/6 - 0s - loss: -5.5456e+00 - 32ms/epoch - 5ms/step
# Epoch 181/1000
# 6/6 - 0s - loss: -5.5264e+00 - 34ms/epoch - 6ms/step
# Epoch 182/1000
# 6/6 - 0s - loss: -5.5558e+00 - 32ms/epoch - 5ms/step
# Epoch 183/1000
# 6/6 - 0s - loss: -5.5648e+00 - 35ms/epoch - 6ms/step
# Epoch 184/1000
# 6/6 - 0s - loss: -5.5357e+00 - 33ms/epoch - 5ms/step
# Epoch 185/1000
# 6/6 - 0s - loss: -5.5682e+00 - 36ms/epoch - 6ms/step
# Epoch 186/1000
# 6/6 - 0s - loss: -5.5274e+00 - 33ms/epoch - 5ms/step
# Epoch 187/1000
# 6/6 - 0s - loss: -5.5508e+00 - 33ms/epoch - 6ms/step
# Epoch 188/1000
# 6/6 - 0s - loss: -5.5091e+00 - 34ms/epoch - 6ms/step
# Epoch 189/1000
# 6/6 - 0s - loss: -5.4822e+00 - 35ms/epoch - 6ms/step
# Epoch 190/1000
# 6/6 - 0s - loss: -5.5004e+00 - 36ms/epoch - 6ms/step
# Epoch 191/1000
# 6/6 - 0s - loss: -5.4825e+00 - 34ms/epoch - 6ms/step
# Epoch 192/1000
# 6/6 - 0s - loss: -5.5317e+00 - 33ms/epoch - 6ms/step
# Epoch 193/1000
# 6/6 - 0s - loss: -5.5498e+00 - 37ms/epoch - 6ms/step
# Epoch 194/1000
# 6/6 - 0s - loss: -5.5331e+00 - 32ms/epoch - 5ms/step
# Epoch 195/1000
# 6/6 - 0s - loss: -5.5604e+00 - 32ms/epoch - 5ms/step
# Epoch 196/1000
# 6/6 - 0s - loss: -5.5465e+00 - 33ms/epoch - 5ms/step
# Epoch 197/1000
# 6/6 - 0s - loss: -5.5489e+00 - 33ms/epoch - 6ms/step
# Epoch 198/1000
# 6/6 - 0s - loss: -5.5476e+00 - 33ms/epoch - 5ms/step
# Epoch 199/1000
# 6/6 - 0s - loss: -5.5686e+00 - 38ms/epoch - 6ms/step
# Epoch 200/1000
# 6/6 - 0s - loss: -5.5633e+00 - 33ms/epoch - 5ms/step
# Epoch 201/1000
# 6/6 - 0s - loss: -5.5146e+00 - 33ms/epoch - 5ms/step
# Epoch 202/1000
# 6/6 - 0s - loss: -5.4478e+00 - 33ms/epoch - 6ms/step
# Epoch 203/1000
# 6/6 - 0s - loss: -5.4957e+00 - 33ms/epoch - 6ms/step
# Epoch 204/1000
# 6/6 - 0s - loss: -5.5423e+00 - 36ms/epoch - 6ms/step
# Epoch 205/1000
# 6/6 - 0s - loss: -5.5421e+00 - 34ms/epoch - 6ms/step
# Epoch 206/1000
# 6/6 - 0s - loss: -5.5435e+00 - 33ms/epoch - 6ms/step
# Epoch 207/1000
# 6/6 - 0s - loss: -5.5506e+00 - 34ms/epoch - 6ms/step
# Epoch 208/1000
# 6/6 - 0s - loss: -5.5678e+00 - 31ms/epoch - 5ms/step
# Epoch 209/1000
# 6/6 - 0s - loss: -5.5446e+00 - 32ms/epoch - 5ms/step
# Epoch 210/1000
# 6/6 - 0s - loss: -5.5609e+00 - 33ms/epoch - 6ms/step
# Epoch 211/1000
# 6/6 - 0s - loss: -5.5258e+00 - 34ms/epoch - 6ms/step
# Epoch 212/1000
# 6/6 - 0s - loss: -5.5120e+00 - 32ms/epoch - 5ms/step
# Epoch 213/1000
# 6/6 - 0s - loss: -5.4887e+00 - 32ms/epoch - 5ms/step
# Epoch 214/1000
# 6/6 - 0s - loss: -5.4781e+00 - 31ms/epoch - 5ms/step
# Epoch 215/1000
# 6/6 - 0s - loss: -5.4508e+00 - 38ms/epoch - 6ms/step
# Epoch 216/1000
# 6/6 - 0s - loss: -5.5051e+00 - 32ms/epoch - 5ms/step
# Epoch 217/1000
# 6/6 - 0s - loss: -5.5313e+00 - 34ms/epoch - 6ms/step
# Epoch 218/1000
# 6/6 - 0s - loss: -5.5801e+00 - 33ms/epoch - 5ms/step
# Epoch 219/1000
# 6/6 - 0s - loss: -5.5496e+00 - 37ms/epoch - 6ms/step
# Epoch 220/1000
# 6/6 - 0s - loss: -5.5350e+00 - 36ms/epoch - 6ms/step
# Epoch 221/1000
# 6/6 - 0s - loss: -5.5392e+00 - 31ms/epoch - 5ms/step
# Epoch 222/1000
# 6/6 - 0s - loss: -5.5866e+00 - 32ms/epoch - 5ms/step
# Epoch 223/1000
# 6/6 - 0s - loss: -5.5605e+00 - 34ms/epoch - 6ms/step
# Epoch 224/1000
# ...
# Epoch 774/1000
# 6/6 - 0s - loss: -6.7044e+00 - 36ms/epoch - 6ms/step
# Epoch 775/1000
# 6/6 - 0s - loss: -6.7013e+00 - 32ms/epoch - 5ms/step
# Epoch 776/1000
# 6/6 - 0s - loss: -6.6932e+00 - 32ms/epoch - 5ms/step
# Epoch 777/1000
# 6/6 - 0s - loss: -6.6935e+00 - 33ms/epoch - 5ms/step
# Epoch 778/1000
# 6/6 - 0s - loss: -6.6988e+00 - 34ms/epoch - 6ms/step
# Epoch 779/1000
# 6/6 - 0s - loss: -6.7016e+00 - 34ms/epoch - 6ms/step
# Epoch 780/1000
# 6/6 - 0s - loss: -6.6964e+00 - 33ms/epoch - 6ms/step
# Epoch 781/1000
# 6/6 - 0s - loss: -6.6926e+00 - 33ms/epoch - 6ms/step
# Epoch 782/1000
# 6/6 - 0s - loss: -6.6977e+00 - 31ms/epoch - 5ms/step
# Epoch 783/1000
# 6/6 - 0s - loss: -6.6992e+00 - 35ms/epoch - 6ms/step
# Epoch 784/1000
# 6/6 - 0s - loss: -6.6991e+00 - 33ms/epoch - 6ms/step
# Epoch 785/1000
# 6/6 - 0s - loss: -6.7004e+00 - 32ms/epoch - 5ms/step
# Epoch 786/1000
# 6/6 - 0s - loss: -6.7068e+00 - 32ms/epoch - 5ms/step
# Epoch 787/1000
# 6/6 - 0s - loss: -6.6951e+00 - 31ms/epoch - 5ms/step
# Epoch 788/1000
# 6/6 - 0s - loss: -6.7030e+00 - 33ms/epoch - 6ms/step
# Epoch 789/1000
# 6/6 - 0s - loss: -6.6950e+00 - 32ms/epoch - 5ms/step
# Epoch 790/1000
# 6/6 - 0s - loss: -6.7072e+00 - 31ms/epoch - 5ms/step
# Epoch 791/1000
# 6/6 - 0s - loss: -6.7034e+00 - 31ms/epoch - 5ms/step
# Epoch 792/1000
# 6/6 - 0s - loss: -6.7023e+00 - 36ms/epoch - 6ms/step
# Epoch 793/1000
# 6/6 - 0s - loss: -6.7044e+00 - 32ms/epoch - 5ms/step
# Epoch 794/1000
# 6/6 - 0s - loss: -6.6884e+00 - 40ms/epoch - 7ms/step
# Epoch 795/1000
# 6/6 - 0s - loss: -6.7035e+00 - 33ms/epoch - 6ms/step
# Epoch 796/1000
# 6/6 - 0s - loss: -6.6917e+00 - 34ms/epoch - 6ms/step
# Epoch 797/1000
# 6/6 - 0s - loss: -6.7034e+00 - 33ms/epoch - 6ms/step
# Epoch 798/1000
# 6/6 - 0s - loss: -6.7011e+00 - 33ms/epoch - 6ms/step
# Epoch 799/1000
# 6/6 - 0s - loss: -6.7061e+00 - 39ms/epoch - 6ms/step
# Epoch 800/1000
# 6/6 - 0s - loss: -6.7001e+00 - 34ms/epoch - 6ms/step
# Epoch 801/1000
# 6/6 - 0s - loss: -6.7030e+00 - 34ms/epoch - 6ms/step
# Epoch 802/1000
# 6/6 - 0s - loss: -6.7010e+00 - 37ms/epoch - 6ms/step
# Epoch 803/1000
# 6/6 - 0s - loss: -6.6998e+00 - 36ms/epoch - 6ms/step
# Epoch 804/1000
# 6/6 - 0s - loss: -6.7082e+00 - 35ms/epoch - 6ms/step
# Epoch 805/1000
# 6/6 - 0s - loss: -6.6946e+00 - 35ms/epoch - 6ms/step
# Epoch 806/1000
# 6/6 - 0s - loss: -6.7045e+00 - 32ms/epoch - 5ms/step
# Epoch 807/1000
# 6/6 - 0s - loss: -6.7075e+00 - 31ms/epoch - 5ms/step
# Epoch 808/1000
# 6/6 - 0s - loss: -6.7037e+00 - 31ms/epoch - 5ms/step
# Epoch 809/1000
# 6/6 - 0s - loss: -6.6981e+00 - 33ms/epoch - 6ms/step
# Epoch 810/1000
# 6/6 - 0s - loss: -6.7102e+00 - 33ms/epoch - 5ms/step
# Epoch 811/1000
# 6/6 - 0s - loss: -6.6976e+00 - 32ms/epoch - 5ms/step
# Epoch 812/1000
# 6/6 - 0s - loss: -6.7115e+00 - 35ms/epoch - 6ms/step
# Epoch 813/1000
# 6/6 - 0s - loss: -6.7131e+00 - 37ms/epoch - 6ms/step
# Epoch 814/1000
# 6/6 - 0s - loss: -6.7000e+00 - 36ms/epoch - 6ms/step
# Epoch 815/1000
# 6/6 - 0s - loss: -6.6974e+00 - 37ms/epoch - 6ms/step
# Epoch 816/1000
# 6/6 - 0s - loss: -6.7095e+00 - 34ms/epoch - 6ms/step
# Epoch 817/1000
# 6/6 - 0s - loss: -6.7104e+00 - 38ms/epoch - 6ms/step
# Epoch 818/1000
# 6/6 - 0s - loss: -6.7015e+00 - 35ms/epoch - 6ms/step
# Epoch 819/1000
# 6/6 - 0s - loss: -6.7122e+00 - 34ms/epoch - 6ms/step
# Epoch 820/1000
# 6/6 - 0s - loss: -6.7056e+00 - 34ms/epoch - 6ms/step
# Epoch 821/1000
# 6/6 - 0s - loss: -6.6803e+00 - 37ms/epoch - 6ms/step
# Epoch 822/1000
# 6/6 - 0s - loss: -6.6358e+00 - 33ms/epoch - 6ms/step
# Epoch 823/1000
# 6/6 - 0s - loss: -6.6138e+00 - 33ms/epoch - 5ms/step
# Epoch 824/1000
# 6/6 - 0s - loss: -6.6101e+00 - 34ms/epoch - 6ms/step
# Epoch 825/1000
# 6/6 - 0s - loss: -6.6197e+00 - 35ms/epoch - 6ms/step
# Epoch 826/1000
# 6/6 - 0s - loss: -6.6195e+00 - 33ms/epoch - 6ms/step
# Epoch 827/1000
# 6/6 - 0s - loss: -6.6303e+00 - 32ms/epoch - 5ms/step
# Epoch 828/1000
# 6/6 - 0s - loss: -6.6459e+00 - 36ms/epoch - 6ms/step
# Epoch 829/1000
# 6/6 - 0s - loss: -6.6640e+00 - 35ms/epoch - 6ms/step
# Epoch 830/1000
# 6/6 - 0s - loss: -6.6654e+00 - 33ms/epoch - 6ms/step
# Epoch 831/1000
# 6/6 - 0s - loss: -6.6759e+00 - 33ms/epoch - 6ms/step
# Epoch 832/1000
# 6/6 - 0s - loss: -6.6746e+00 - 36ms/epoch - 6ms/step
# Epoch 833/1000
# 6/6 - 0s - loss: -6.6656e+00 - 35ms/epoch - 6ms/step
# Epoch 834/1000
# 6/6 - 0s - loss: -6.6701e+00 - 32ms/epoch - 5ms/step
# Epoch 835/1000
# 6/6 - 0s - loss: -6.6890e+00 - 33ms/epoch - 6ms/step
# Epoch 836/1000
# 6/6 - 0s - loss: -6.6864e+00 - 34ms/epoch - 6ms/step
# Epoch 837/1000
# 6/6 - 0s - loss: -6.6948e+00 - 31ms/epoch - 5ms/step
# Epoch 838/1000
# 6/6 - 0s - loss: -6.6931e+00 - 34ms/epoch - 6ms/step
# Epoch 839/1000
# 6/6 - 0s - loss: -6.7037e+00 - 31ms/epoch - 5ms/step
# Epoch 840/1000
# 6/6 - 0s - loss: -6.7053e+00 - 32ms/epoch - 5ms/step
# Epoch 841/1000
# 6/6 - 0s - loss: -6.6968e+00 - 33ms/epoch - 5ms/step
# Epoch 842/1000
# 6/6 - 0s - loss: -6.6945e+00 - 31ms/epoch - 5ms/step
# Epoch 843/1000
# 6/6 - 0s - loss: -6.6954e+00 - 34ms/epoch - 6ms/step
# Epoch 844/1000
# 6/6 - 0s - loss: -6.7032e+00 - 32ms/epoch - 5ms/step
# Epoch 845/1000
# 6/6 - 0s - loss: -6.6968e+00 - 33ms/epoch - 5ms/step
# Epoch 846/1000
# 6/6 - 0s - loss: -6.6983e+00 - 35ms/epoch - 6ms/step
# Epoch 847/1000
# 6/6 - 0s - loss: -6.6995e+00 - 34ms/epoch - 6ms/step
# Epoch 848/1000
# 6/6 - 0s - loss: -6.7087e+00 - 35ms/epoch - 6ms/step
# Epoch 849/1000
# 6/6 - 0s - loss: -6.7069e+00 - 31ms/epoch - 5ms/step
# Epoch 850/1000
# 6/6 - 0s - loss: -6.7063e+00 - 33ms/epoch - 5ms/step
# Epoch 851/1000
# 6/6 - 0s - loss: -6.6975e+00 - 35ms/epoch - 6ms/step
# Epoch 852/1000
# 6/6 - 0s - loss: -6.6988e+00 - 37ms/epoch - 6ms/step
# Epoch 853/1000
# 6/6 - 0s - loss: -6.7111e+00 - 33ms/epoch - 6ms/step
# Epoch 854/1000
# 6/6 - 0s - loss: -6.7067e+00 - 32ms/epoch - 5ms/step
# Epoch 855/1000
# 6/6 - 0s - loss: -6.7068e+00 - 32ms/epoch - 5ms/step
# Epoch 856/1000
# 6/6 - 0s - loss: -6.7115e+00 - 37ms/epoch - 6ms/step
# Epoch 857/1000
# 6/6 - 0s - loss: -6.7167e+00 - 34ms/epoch - 6ms/step
# Epoch 858/1000
# 6/6 - 0s - loss: -6.7083e+00 - 32ms/epoch - 5ms/step
# Epoch 859/1000
# 6/6 - 0s - loss: -6.7134e+00 - 32ms/epoch - 5ms/step
# Epoch 860/1000
# 6/6 - 0s - loss: -6.7077e+00 - 34ms/epoch - 6ms/step
# Epoch 861/1000
# 6/6 - 0s - loss: -6.6969e+00 - 32ms/epoch - 5ms/step
# Epoch 862/1000
# 6/6 - 0s - loss: -6.6809e+00 - 33ms/epoch - 5ms/step
# Epoch 863/1000
# 6/6 - 0s - loss: -6.6709e+00 - 34ms/epoch - 6ms/step
# Epoch 864/1000
# 6/6 - 0s - loss: -6.6842e+00 - 33ms/epoch - 6ms/step
# Epoch 865/1000
# 6/6 - 0s - loss: -6.6835e+00 - 33ms/epoch - 5ms/step
# Epoch 866/1000
# 6/6 - 0s - loss: -6.6861e+00 - 32ms/epoch - 5ms/step
# Epoch 867/1000
# 6/6 - 0s - loss: -6.6819e+00 - 33ms/epoch - 6ms/step
# Epoch 868/1000
# 6/6 - 0s - loss: -6.6935e+00 - 35ms/epoch - 6ms/step
# Epoch 869/1000
# 6/6 - 0s - loss: -6.6920e+00 - 32ms/epoch - 5ms/step
# Epoch 870/1000
# 6/6 - 0s - loss: -6.6999e+00 - 34ms/epoch - 6ms/step
# Epoch 871/1000
# 6/6 - 0s - loss: -6.7033e+00 - 32ms/epoch - 5ms/step
# Epoch 872/1000
# 6/6 - 0s - loss: -6.7076e+00 - 34ms/epoch - 6ms/step
# Epoch 873/1000
# 6/6 - 0s - loss: -6.7153e+00 - 37ms/epoch - 6ms/step
# Epoch 874/1000
# 6/6 - 0s - loss: -6.7159e+00 - 33ms/epoch - 5ms/step
# Epoch 875/1000
# 6/6 - 0s - loss: -6.7145e+00 - 31ms/epoch - 5ms/step
# Epoch 876/1000
# 6/6 - 0s - loss: -6.7168e+00 - 33ms/epoch - 5ms/step
# Epoch 877/1000
# 6/6 - 0s - loss: -6.7215e+00 - 33ms/epoch - 6ms/step
# Epoch 878/1000
# 6/6 - 0s - loss: -6.7123e+00 - 32ms/epoch - 5ms/step
# Epoch 879/1000
# 6/6 - 0s - loss: -6.7110e+00 - 31ms/epoch - 5ms/step
# Epoch 880/1000
# 6/6 - 0s - loss: -6.7201e+00 - 34ms/epoch - 6ms/step
# Epoch 881/1000
# 6/6 - 0s - loss: -6.7098e+00 - 39ms/epoch - 6ms/step
# Epoch 882/1000
# 6/6 - 0s - loss: -6.7175e+00 - 31ms/epoch - 5ms/step
# Epoch 883/1000
# 6/6 - 0s - loss: -6.7136e+00 - 31ms/epoch - 5ms/step
# Epoch 884/1000
# 6/6 - 0s - loss: -6.7199e+00 - 34ms/epoch - 6ms/step
# Epoch 885/1000
# 6/6 - 0s - loss: -6.7200e+00 - 34ms/epoch - 6ms/step
# Epoch 886/1000
# 6/6 - 0s - loss: -6.7193e+00 - 34ms/epoch - 6ms/step
# Epoch 887/1000
# 6/6 - 0s - loss: -6.7212e+00 - 33ms/epoch - 6ms/step
# Epoch 888/1000
# 6/6 - 0s - loss: -6.7196e+00 - 34ms/epoch - 6ms/step
# Epoch 889/1000
# 6/6 - 0s - loss: -6.7159e+00 - 31ms/epoch - 5ms/step
# Epoch 890/1000
# 6/6 - 0s - loss: -6.7195e+00 - 31ms/epoch - 5ms/step
# Epoch 891/1000
# 6/6 - 0s - loss: -6.7191e+00 - 34ms/epoch - 6ms/step
# Epoch 892/1000
# 6/6 - 0s - loss: -6.7174e+00 - 30ms/epoch - 5ms/step
# Epoch 893/1000
# 6/6 - 0s - loss: -6.7162e+00 - 37ms/epoch - 6ms/step
# Epoch 894/1000
# 6/6 - 0s - loss: -6.7262e+00 - 33ms/epoch - 5ms/step
# Epoch 895/1000
# 6/6 - 0s - loss: -6.7177e+00 - 34ms/epoch - 6ms/step
# Epoch 896/1000
# 6/6 - 0s - loss: -6.7169e+00 - 32ms/epoch - 5ms/step
# Epoch 897/1000
# 6/6 - 0s - loss: -6.7152e+00 - 33ms/epoch - 6ms/step
# Epoch 898/1000
# 6/6 - 0s - loss: -6.7223e+00 - 32ms/epoch - 5ms/step
# Epoch 899/1000
# 6/6 - 0s - loss: -6.7077e+00 - 38ms/epoch - 6ms/step
# Epoch 900/1000
# 6/6 - 0s - loss: -6.7126e+00 - 33ms/epoch - 5ms/step
# Epoch 901/1000
# 6/6 - 0s - loss: -6.7074e+00 - 34ms/epoch - 6ms/step
# Epoch 902/1000
# 6/6 - 0s - loss: -6.7019e+00 - 38ms/epoch - 6ms/step
# Epoch 903/1000
# 6/6 - 0s - loss: -6.7178e+00 - 42ms/epoch - 7ms/step
# Epoch 904/1000
# 6/6 - 0s - loss: -6.7085e+00 - 34ms/epoch - 6ms/step
# Epoch 905/1000
# 6/6 - 0s - loss: -6.7194e+00 - 34ms/epoch - 6ms/step
# Epoch 906/1000
# 6/6 - 0s - loss: -6.7102e+00 - 34ms/epoch - 6ms/step
# Epoch 907/1000
# 6/6 - 0s - loss: -6.7139e+00 - 36ms/epoch - 6ms/step
# Epoch 908/1000
# 6/6 - 0s - loss: -6.7142e+00 - 35ms/epoch - 6ms/step
# Epoch 909/1000
# 6/6 - 0s - loss: -6.7141e+00 - 41ms/epoch - 7ms/step
# Epoch 910/1000
# 6/6 - 0s - loss: -6.7077e+00 - 39ms/epoch - 6ms/step
# Epoch 911/1000
# 6/6 - 0s - loss: -6.7170e+00 - 41ms/epoch - 7ms/step
# Epoch 912/1000
# 6/6 - 0s - loss: -6.7234e+00 - 34ms/epoch - 6ms/step
# Epoch 913/1000
# 6/6 - 0s - loss: -6.7194e+00 - 36ms/epoch - 6ms/step
# Epoch 914/1000
# 6/6 - 0s - loss: -6.7103e+00 - 31ms/epoch - 5ms/step
# Epoch 915/1000
# 6/6 - 0s - loss: -6.7102e+00 - 35ms/epoch - 6ms/step
# Epoch 916/1000
# 6/6 - 0s - loss: -6.7107e+00 - 36ms/epoch - 6ms/step
# Epoch 917/1000
# 6/6 - 0s - loss: -6.7138e+00 - 34ms/epoch - 6ms/step
# Epoch 918/1000
# 6/6 - 0s - loss: -6.7112e+00 - 36ms/epoch - 6ms/step
# Epoch 919/1000
# 6/6 - 0s - loss: -6.7123e+00 - 36ms/epoch - 6ms/step
# Epoch 920/1000
# 6/6 - 0s - loss: -6.7197e+00 - 35ms/epoch - 6ms/step
# Epoch 921/1000
# 6/6 - 0s - loss: -6.7120e+00 - 35ms/epoch - 6ms/step
# Epoch 922/1000
# 6/6 - 0s - loss: -6.7221e+00 - 36ms/epoch - 6ms/step
# Epoch 923/1000
# 6/6 - 0s - loss: -6.7186e+00 - 33ms/epoch - 5ms/step
# Epoch 924/1000
# 6/6 - 0s - loss: -6.7071e+00 - 33ms/epoch - 6ms/step
# Epoch 925/1000
# 6/6 - 0s - loss: -6.7150e+00 - 33ms/epoch - 5ms/step
# Epoch 926/1000
# 6/6 - 0s - loss: -6.7059e+00 - 36ms/epoch - 6ms/step
# Epoch 927/1000
# 6/6 - 0s - loss: -6.7122e+00 - 34ms/epoch - 6ms/step
# Epoch 928/1000
# 6/6 - 0s - loss: -6.7003e+00 - 36ms/epoch - 6ms/step
# Epoch 929/1000
# 6/6 - 0s - loss: -6.6983e+00 - 33ms/epoch - 5ms/step
# Epoch 930/1000
# 6/6 - 0s - loss: -6.7026e+00 - 32ms/epoch - 5ms/step
# Epoch 931/1000
# 6/6 - 0s - loss: -6.7028e+00 - 36ms/epoch - 6ms/step
# Epoch 932/1000
# 6/6 - 0s - loss: -6.7092e+00 - 32ms/epoch - 5ms/step
# Epoch 933/1000
# 6/6 - 0s - loss: -6.7104e+00 - 31ms/epoch - 5ms/step
# Epoch 934/1000
# 6/6 - 0s - loss: -6.7080e+00 - 31ms/epoch - 5ms/step
# Epoch 935/1000
# 6/6 - 0s - loss: -6.7078e+00 - 33ms/epoch - 5ms/step
# Epoch 936/1000
# 6/6 - 0s - loss: -6.7075e+00 - 35ms/epoch - 6ms/step
# Epoch 937/1000
# 6/6 - 0s - loss: -6.7097e+00 - 31ms/epoch - 5ms/step
# Epoch 938/1000
# 6/6 - 0s - loss: -6.7081e+00 - 34ms/epoch - 6ms/step
# Epoch 939/1000
# 6/6 - 0s - loss: -6.7012e+00 - 33ms/epoch - 5ms/step
# Epoch 940/1000
# 6/6 - 0s - loss: -6.7107e+00 - 32ms/epoch - 5ms/step
# Epoch 941/1000
# 6/6 - 0s - loss: -6.7089e+00 - 32ms/epoch - 5ms/step
# Epoch 942/1000
# 6/6 - 0s - loss: -6.7133e+00 - 33ms/epoch - 5ms/step
# Epoch 943/1000
# 6/6 - 0s - loss: -6.7161e+00 - 31ms/epoch - 5ms/step
# Epoch 944/1000
# 6/6 - 0s - loss: -6.7161e+00 - 31ms/epoch - 5ms/step
# Epoch 945/1000
# 6/6 - 0s - loss: -6.7113e+00 - 35ms/epoch - 6ms/step
# Epoch 946/1000
# 6/6 - 0s - loss: -6.7117e+00 - 34ms/epoch - 6ms/step
# Epoch 947/1000
# 6/6 - 0s - loss: -6.7127e+00 - 34ms/epoch - 6ms/step
# Epoch 948/1000
# 6/6 - 0s - loss: -6.7206e+00 - 33ms/epoch - 5ms/step
# Epoch 949/1000
# 6/6 - 0s - loss: -6.7196e+00 - 33ms/epoch - 5ms/step
# Epoch 950/1000
# 6/6 - 0s - loss: -6.7181e+00 - 32ms/epoch - 5ms/step
# Epoch 951/1000
# 6/6 - 0s - loss: -6.7073e+00 - 32ms/epoch - 5ms/step
# Epoch 952/1000
# 6/6 - 0s - loss: -6.7169e+00 - 34ms/epoch - 6ms/step
# Epoch 953/1000
# 6/6 - 0s - loss: -6.7147e+00 - 33ms/epoch - 5ms/step
# Epoch 954/1000
# 6/6 - 0s - loss: -6.7065e+00 - 32ms/epoch - 5ms/step
# Epoch 955/1000
# 6/6 - 0s - loss: -6.7092e+00 - 32ms/epoch - 5ms/step
# Epoch 956/1000
# 6/6 - 0s - loss: -6.7047e+00 - 32ms/epoch - 5ms/step
# Epoch 957/1000
# 6/6 - 0s - loss: -6.7050e+00 - 33ms/epoch - 5ms/step
# Epoch 958/1000
# 6/6 - 0s - loss: -6.7056e+00 - 35ms/epoch - 6ms/step
# Epoch 959/1000
# 6/6 - 0s - loss: -6.7186e+00 - 34ms/epoch - 6ms/step
# Epoch 960/1000
# 6/6 - 0s - loss: -6.7242e+00 - 35ms/epoch - 6ms/step
# Epoch 961/1000
# 6/6 - 0s - loss: -6.7136e+00 - 33ms/epoch - 6ms/step
# Epoch 962/1000
# 6/6 - 0s - loss: -6.5691e+00 - 34ms/epoch - 6ms/step
# Epoch 963/1000
# 6/6 - 0s - loss: -6.4468e+00 - 33ms/epoch - 6ms/step
# Epoch 964/1000
# 6/6 - 0s - loss: -6.6349e+00 - 32ms/epoch - 5ms/step
# Epoch 965/1000
# 6/6 - 0s - loss: -6.7003e+00 - 34ms/epoch - 6ms/step
# Epoch 966/1000
# 6/6 - 0s - loss: -6.7094e+00 - 34ms/epoch - 6ms/step
# Epoch 967/1000
# 6/6 - 0s - loss: -6.7058e+00 - 33ms/epoch - 6ms/step
# Epoch 968/1000
# 6/6 - 0s - loss: -6.7132e+00 - 31ms/epoch - 5ms/step
# Epoch 969/1000
# 6/6 - 0s - loss: -6.7076e+00 - 32ms/epoch - 5ms/step
# Epoch 970/1000
# 6/6 - 0s - loss: -6.6975e+00 - 36ms/epoch - 6ms/step
# Epoch 971/1000
# 6/6 - 0s - loss: -6.7100e+00 - 34ms/epoch - 6ms/step
# Epoch 972/1000
# 6/6 - 0s - loss: -6.7041e+00 - 34ms/epoch - 6ms/step
# Epoch 973/1000
# 6/6 - 0s - loss: -6.7021e+00 - 35ms/epoch - 6ms/step
# Epoch 974/1000
# 6/6 - 0s - loss: -6.7120e+00 - 36ms/epoch - 6ms/step
# Epoch 975/1000
# 6/6 - 0s - loss: -6.7146e+00 - 35ms/epoch - 6ms/step
# Epoch 976/1000
# 6/6 - 0s - loss: -6.7065e+00 - 36ms/epoch - 6ms/step
# Epoch 977/1000
# 6/6 - 0s - loss: -6.7112e+00 - 33ms/epoch - 5ms/step
# Epoch 978/1000
# 6/6 - 0s - loss: -6.6853e+00 - 33ms/epoch - 5ms/step
# Epoch 979/1000
# 6/6 - 0s - loss: -6.5187e+00 - 33ms/epoch - 6ms/step
# Epoch 980/1000
# 6/6 - 0s - loss: -6.3543e+00 - 32ms/epoch - 5ms/step
# Epoch 981/1000
# 6/6 - 0s - loss: -6.3132e+00 - 31ms/epoch - 5ms/step
# Epoch 982/1000
# 6/6 - 0s - loss: -6.3977e+00 - 32ms/epoch - 5ms/step
# Epoch 983/1000
# 6/6 - 0s - loss: -6.5163e+00 - 37ms/epoch - 6ms/step
# Epoch 984/1000
# 6/6 - 0s - loss: -6.5726e+00 - 34ms/epoch - 6ms/step
# Epoch 985/1000
# 6/6 - 0s - loss: -6.6358e+00 - 32ms/epoch - 5ms/step
# Epoch 986/1000
# 6/6 - 0s - loss: -6.6423e+00 - 33ms/epoch - 5ms/step
# Epoch 987/1000
# 6/6 - 0s - loss: -6.6668e+00 - 34ms/epoch - 6ms/step
# Epoch 988/1000
# 6/6 - 0s - loss: -6.6634e+00 - 33ms/epoch - 6ms/step
# Epoch 989/1000
# 6/6 - 0s - loss: -6.6674e+00 - 30ms/epoch - 5ms/step
# Epoch 990/1000
# 6/6 - 0s - loss: -6.6846e+00 - 32ms/epoch - 5ms/step
# Epoch 991/1000
# 6/6 - 0s - loss: -6.6826e+00 - 33ms/epoch - 5ms/step
# Epoch 992/1000
# 6/6 - 0s - loss: -6.6900e+00 - 31ms/epoch - 5ms/step
# Epoch 993/1000
# 6/6 - 0s - loss: -6.6916e+00 - 32ms/epoch - 5ms/step
# Epoch 994/1000
# 6/6 - 0s - loss: -6.6972e+00 - 33ms/epoch - 5ms/step
# Epoch 995/1000
# 6/6 - 0s - loss: -6.6982e+00 - 34ms/epoch - 6ms/step
# Epoch 996/1000
# 6/6 - 0s - loss: -6.6890e+00 - 32ms/epoch - 5ms/step
# Epoch 997/1000
# 6/6 - 0s - loss: -6.6900e+00 - 33ms/epoch - 6ms/step
# Epoch 998/1000
# 6/6 - 0s - loss: -6.6919e+00 - 37ms/epoch - 6ms/step
# Epoch 999/1000
# 6/6 - 0s - loss: -6.6885e+00 - 32ms/epoch - 5ms/step
# Epoch 1000/1000
# 6/6 - 0s - loss: -6.6979e+00 - 32ms/epoch - 5ms/step
#
# Fold 4 prediction cv gini_0: 0.92009
#
#
# Fold 4 prediction cv gini_1: 0.92870
#
#
# Fold 4 prediction cv gini_2: 0.92201
#
#
# Fold 4 prediction cv gini_3: 0.91611
#
#
# Fold 4 prediction cv gini_4: 0.90770
#
#
# Fold 4 prediction cv gini_5: 0.92087
#
#
# Fold 4 prediction cv gini_6: 0.92698
#
# Mean validation fold gini_0: 0.93582
#
# Mean validation fold gini_1: 0.93707
#
# Mean validation fold gini_2: 0.93496
#
# Mean validation fold gini_3: 0.92884
#
# Mean validation fold gini_4: 0.92406
#
# Mean validation fold gini_5: 0.92214
#
# Mean validation fold gini_6: 0.92134

# %% [markdown]
# #### 1.6.2 Summary and plot the MLP model <a id='1.6.2_summary_plot_model'></a>

# %%
plot_model(NN, to_file='/content/drive/My Drive/Colab_data/covid19/model_plot_MLP_7d.png', show_shapes=True, show_layer_names=True)

# %%
print(NN.summary())
with open('/content/drive/My Drive/Colab_data/covid19/model_summary_MLP_7d.txt', 'w') as f:
    with redirect_stdout(f):
        NN.summary()
# Out:
# Model: "model_99"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_793 (InputLayer)         [(None, 1)]          0           []
#
#  input_794 (InputLayer)         [(None, 1)]          0           []
#
#  input_795 (InputLayer)         [(None, 1)]          0           []
#
#  input_796 (InputLayer)         [(None, 1)]          0           []
#
#  input_797 (InputLayer)         [(None, 1)]          0           []
#
#  input_798 (InputLayer)         [(None, 1)]          0           []
#
#  input_799 (InputLayer)         [(None, 1)]          0           []
#
#  embedding_693 (Embedding)      (None, 1, 9)         207         ['input_793[0][0]']
#
#  embedding_694 (Embedding)      (None, 1, 1)         2           ['input_794[0][0]']
#
#  embedding_695 (Embedding)      (None, 1, 6)         72          ['input_795[0][0]']
#
#  embedding_696 (Embedding)      (None, 1, 11)        341         ['input_796[0][0]']
#
#  embedding_697 (Embedding)      (None, 1, 15)        795         ['input_797[0][0]']
#
#  embedding_698 (Embedding)      (None, 1, 5)         35          ['input_798[0][0]']
#
#  embedding_699 (Embedding)      (None, 1, 2)         4           ['input_799[0][0]']
#
#  input_800 (InputLayer)         [(None, 25)]         0           []
#
#  reshape_693 (Reshape)          (None, 9)            0           ['embedding_693[0][0]']
#
#  reshape_694 (Reshape)          (None, 1)            0           ['embedding_694[0][0]']
#
#  reshape_695 (Reshape)          (None, 6)            0           ['embedding_695[0][0]']
#
#  reshape_696 (Reshape)          (None, 11)           0           ['embedding_696[0][0]']
#
#  reshape_697 (Reshape)          (None, 15)           0           ['embedding_697[0][0]']
#
#  reshape_698 (Reshape)          (None, 5)            0           ['embedding_698[0][0]']
#
#  reshape_699 (Reshape)          (None, 2)            0           ['embedding_699[0][0]']
#
#  dense_495 (Dense)              (None, 19)           494         ['input_800[0][0]']
#
#  concatenate_99 (Concatenate)   (None, 68)           0           ['reshape_693[0][0]',
#                                                                   'reshape_694[0][0]',
#                                                                   'reshape_695[0][0]',
#                                                                   'reshape_696[0][0]',
#                                                                   'reshape_697[0][0]',
#                                                                   'reshape_698[0][0]',
#                                                                   'reshape_699[0][0]',
#                                                                   'dense_495[0][0]']
#
#  dense_496 (Dense)              (None, 90)           6210        ['concatenate_99[0][0]']
#
#  dropout_297 (Dropout)          (None, 90)           0           ['dense_496[0][0]']
#
#  dense_497 (Dense)              (None, 40)           3640        ['dropout_297[0][0]']
#
#  dropout_298 (Dropout)          (None, 40)           0           ['dense_497[0][0]']
#
#  dense_498 (Dense)              (None, 10)           410         ['dropout_298[0][0]']
#
#  dropout_299 (Dropout)          (None, 10)           0           ['dense_498[0][0]']
#
#  dense_499 (Dense)              (None, 7)            77          ['dropout_299[0][0]']
#
# ==================================================================================================
# Total params: 12,287
# Trainable params: 12,287
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## 1.7 Organize and evaluate model performance <a id='1.7_organize_evaludate_model'></a>

# %% [markdown]
# #### 1.7.1 Organize and evaluate model performance: train set <a id='1.7.1_organize_evaludate_model_train'></a>

# %%
# average train_preds across folds to get train_y_pred
train_y_pred_fold = numpy.empty((len(train_idx_fold[0]), n_steps_out, len(train_idx_fold)))
train_y_pred_fold[:]=np.NaN
for i, train_idx in enumerate(train_idx_fold): 
    train_y_pred_fold[train_idx,:,i] = train_preds[i]
train_y_pred = np.nanmean(train_y_pred_fold, axis=2)

rez_MLP_7d_train = {}
train_set_idx = np.isnan(train_y_pred).sum(axis=1)==0
rez_MLP_7d_train['timestamp'] = [train_timestamp[i] for i, logic in enumerate(train_set_idx) if logic ==True]
rez_MLP_7d_train['country'] = [train_country[i] for i, logic in enumerate(train_set_idx) if logic ==True]
rez_MLP_7d_train['X'] = train_X[train_set_idx,:] # note that variables are scaled and preprocessed for embedding 
rez_MLP_7d_train['y'] = scaler_y.inverse_transform(train_y)[train_set_idx,:] # back to the original unit (cases per million)
rez_MLP_7d_train['y_pred'] = scaler_y.inverse_transform(train_y_pred)[train_set_idx,:] 
rez_MLP_7d_train['rmse'] = rmse_y_y_pred(rez_MLP_7d_train, n_steps_out)

# %% [markdown]
# #### 1.7.2 Organize and evaluate model performance: validation set <a id='1.7.2_organize_evaludate_model_validation'></a>

# %%
# average val_preds across folds to get val_y_pred
val_y_pred_fold = numpy.empty((len(train_idx_fold[0]), n_steps_out, len(train_idx_fold)))
val_y_pred_fold[:]=np.NaN
for i, val_idx in enumerate(val_idx_fold): 
    val_y_pred_fold[val_idx,:,i] = val_preds[i]
val_y_pred = np.nanmean(val_y_pred_fold, axis=2)

rez_MLP_7d_val = {}
val_set_idx = np.isnan(val_y_pred).sum(axis=1)==0
rez_MLP_7d_val['timestamp'] = [train_timestamp[i] for i, logic in enumerate(val_set_idx) if logic ==True]
rez_MLP_7d_val['country'] = [train_country[i] for i, logic in enumerate(val_set_idx) if logic ==True]
rez_MLP_7d_val['X'] = train_X[val_set_idx,:] # note that variables are scaled and preprocessed for embedding 
rez_MLP_7d_val['y'] = scaler_y.inverse_transform(train_y)[val_set_idx,:] # back to the original unit (cases per million)
rez_MLP_7d_val['y_pred'] = scaler_y.inverse_transform(val_y_pred)[val_set_idx,:] 
rez_MLP_7d_val['rmse'] = rmse_y_y_pred(rez_MLP_7d_val, n_steps_out)

# %% [markdown]
# #### 1.7.3 Organize and evaluate model performance: test set <a id='1.7.3_organize_evaludate_model_test'></a>

# %%
rez_MLP_7d_test = {}
rez_MLP_7d_test['timestamp'] = test_timestamp
rez_MLP_7d_test['country'] = test_country
rez_MLP_7d_test['X'] = test_X # note that variables are scaled and preprocessed for embedding 
rez_MLP_7d_test['y'] = scaler_y.inverse_transform(test_y)
rez_MLP_7d_test['y_pred'] = scaler_y.inverse_transform(test_y_pred)
rez_MLP_7d_test['rmse'] = rmse_y_y_pred(rez_MLP_7d_test, n_steps_out)

# %% [markdown]
# #### 1.7.4 Organize and evaluate model performance: save data<a id='1.7.4_organize_evaludate_model_save'></a>

# %%
rez_MLP_7d = {'train':rez_MLP_7d_train, 'validation':rez_MLP_7d_val, 'test':rez_MLP_7d_test}

filePath_pickle = Path('/content/drive/My Drive/Colab_data/covid19/covid19_MLP_7d_with_lagging_shorter_test_period_colab.pickle')
with open(filePath_pickle, 'wb') as f:
    pickle.dump(rez_MLP_7d, f)

# %%
# load the saved dictionary from pickle file
# filePath_pickle = Path('/Users/parkj/Documents/pyDat/pyDatCode/covid19/covid19_MLP_7d_with_lagging.pickle')
# with open(filePath_pickle, 'rb') as f:
#     rez_MLP_7d = pickle.load(f)

# %% [markdown]
# #### 1.7.5 Organize and evaluate model performance: plot <a id='1.7.5_organize_evaludate_model_plot'></a>

# %%
plot_test_set(rez_MLP_7d_test, dict_country, 'test', n_steps_out=7)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
